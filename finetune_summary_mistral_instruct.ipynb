# %% [markdown]
# # Dependencies

# %%
# !pip install -q rouge_score
# !pip install -q datasets
# !pip install -q transformers
# !pip install -q evaluate
# !pip install -q accelerate
# !pip install -q -i https://pypi.org/simple/ bitsandbytes
# !pip install -q peft
# !pip install -q trl
# !pip install -q tqdm
# !pip install -q pd
# !pip install -q huggingface_hub
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge_score (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.3/527.3 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 12.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.7/105.7 kB 9.1 MB/s eta 0:00:00

# %%
import torch
import transformers
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM, TrainingArguments, Trainer, pipeline, BitsAndBytesConfig, DataCollatorForLanguageModeling, GenerationConfig
from peft import LoraConfig, get_peft_model, TaskType, PeftModel, PeftConfig, prepare_model_for_kbit_training, AutoPeftModelForCausalLM
from trl import SFTTrainer
import evaluate

import pandas as pd

import time
from tqdm import tqdm

# %% [markdown]
# #Data Preparation/Preprocessing

# %%
MODEL_CHECKPOINT = 'mistralai/Mistral-7B-Instruct-v0.2'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset,DatasetDict,load_metric

# Loading custom dataset
path = "/content/drive/MyDrive/finetune_sum/data/train2.csv"
dataset = load_dataset('csv', data_files= path)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 2992
#     })
# })

# %%
# Split the dataset into train and test+validation sets
split_dataset = dataset['train'].train_test_split(test_size=0.2)
# Further split the test+validation set into validation and test sets
test_valid_split = split_dataset['test'].train_test_split(test_size=0.5)

# Combine splits into a single DatasetDict
data = DatasetDict({
    'train': split_dataset['train'],
    'validation': test_valid_split['train'],
    'test': test_valid_split['test']
})

# Example output
print(data)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 2393
#     })
#     validation: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 299
#     })
#     test: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 300
#     })
# })

# %%
print(data["train"][2]["dialogue"])
# Out:
# Sidratul Sadia: Hello?
# Sidratul Sadia: Good morning.
# Jane: Hi, Dina. It's Jane. How are you going?
# Sidratul Sadia: Yeah. Fine. Thank you for asking.
# Jane: Sorry. I was at work. I'm at work. I was on the phone.Sorry.
# Sidratul Sadia: Uh, no. No worries.
# Sidratul Sadia: No worries. So it's regarding the installation date. Give me one second. Let
# Sidratul Sadia: me check my schedule one more time. Okay. So would you be
# Sidratul Sadia: available, uh, tomorrow to take the installation?
# Jane: Yes, please. Yep. The sooner I get this in, the better.
# Sidratul Sadia: Alright. So I just need to reconfirm few more things with you. Your house is
# Sidratul Sadia: a single storey house or it's a double storey house?
# Jane: Yes. It is. Single single story.
# Sidratul Sadia: Okay. And the address is 6 Summercourt, Harness, Victoria 3337?
# Jane: Yep.
# Sidratul Sadia: Alright.
# Sidratul Sadia: And, uh, k. So so for 300 liter SLA, your quoted amount is
# Sidratul Sadia: $2,615, and I can see that your finance have been approved.
# Jane: Mhmm.
# Sidratul Sadia: So, yeah, I just want to let you know that, uh, maybe the
# Sidratul Sadia: person told you that
# Sidratul Sadia: the 10 meter riding we are covering for you, and he has
# Sidratul Sadia: he hasn't included any wiring.
# Sidratul Sadia: Onto your quote. But if the wiring goes above 10 meter, per meter will cost you 30
# Sidratul Sadia: $3 that you need to pay up front on to my team.
# Jane: That's alright. It shouldn't be because the my hot water service in my electrical box are, like,not not even 5 meters away from each other. They're they're very close. It's only a
# Sidratul Sadia: Okay. It's
# Jane: okay, a fence separating them. So I'll have to get someone to take the fenceoff so he can have access to the um, the hot water the old hot water service.
# Sidratul Sadia: Okay. And, uh, no worries.
# Sidratul Sadia: We will see what happens tomorrow.
# Sidratul Sadia: And, yeah, we are going to take with the old system and replace
# Sidratul Sadia: the new one. And after all the work is done, my team is gonna give you a few
# Sidratul Sadia: documents. Please make sure to sign them back. So on tomorrow, which is 14th August,
# Sidratul Sadia: Wednesday, my team is gonna give you a call 30 or 40 minutes prior between
# Sidratul Sadia: 8 AM to 3 PM.
# Jane: Alright. No worries. Now I don't have to be there personally myselfCan one of my son sign the paperwork, or do I have to sign it?
# Sidratul Sadia: Uh, anyone can sign and attend it.
# Jane: Okay.No worries. Alright. Perfect.
# Sidratul Sadia: Yeah. Alright.
# Sidratul Sadia: Thank you.
# Sidratul Sadia: Thank you.
# Jane: Thank you. Thanks, Tina. Have a good day. Bye. Bye.
# Sidratul Sadia: Mhmm. You too. Bye.

# %%
print(data["train"][2]["summary"])
# Out:
# Call Summary:
# 1. The address for installation is 6 Summercourt, Harness, Victoria 3337.
# 2. The house is a single-storey or double-storey.
# 3. The sooner the installation is done, the better.
# 4. Additional wiring beyond 10 meters will cost $3 per meter, payable upfront to Sidratul Sadia's team.
# 5. The hot water service and electrical box are less than 5 meters apart.

# %% [markdown]
# ##Formatting data in mistral format & HF login
#
# *   <\s>[INST] What is your favourite condiment? [/INST]
# Response.<\s>

# %%
def preprocess_data(example):
  dialogue = example["dialogue"]
  summary = example["summary"]
  prompt = f"""<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
{dialogue}[/INST]
{summary}
</s>"""
  return {"text": prompt}

# %%
data_preprocessed = data.map(preprocess_data,remove_columns=["id", "dialogue", "summary"])

# %%
data_preprocessed
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 2393
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 299
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 300
#     })
# })

# %%
"""
merged both dialogue and label summaries into a training ready prompt-response format.
"""
print(data_preprocessed["train"][2]["text"])
# Out:
# <s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Sidratul Sadia: Hello?
# Sidratul Sadia: Good morning.
# Jane: Hi, Dina. It's Jane. How are you going?
# Sidratul Sadia: Yeah. Fine. Thank you for asking.
# Jane: Sorry. I was at work. I'm at work. I was on the phone.Sorry.
# Sidratul Sadia: Uh, no. No worries.
# Sidratul Sadia: No worries. So it's regarding the installation date. Give me one second. Let
# Sidratul Sadia: me check my schedule one more time. Okay. So would you be
# Sidratul Sadia: available, uh, tomorrow to take the installation?
# Jane: Yes, please. Yep. The sooner I get this in, the better.
# Sidratul Sadia: Alright. So I just need to reconfirm few more things with you. Your house is
# Sidratul Sadia: a single storey house or it's a double storey house?
# Jane: Yes. It is. Single single story.
# Sidratul Sadia: Okay. And the address is 6 Summercourt, Harness, Victoria 3337?
# Jane: Yep.
# Sidratul Sadia: Alright.
# Sidratul Sadia: And, uh, k. So so for 300 liter SLA, your quoted amount is
# Sidratul Sadia: $2,615, and I can see that your finance have been approved.
# Jane: Mhmm.
# Sidratul Sadia: So, yeah, I just want to let you know that, uh, maybe the
# Sidratul Sadia: person told you that
# Sidratul Sadia: the 10 meter riding we are covering for you, and he has
# Sidratul Sadia: he hasn't included any wiring.
# Sidratul Sadia: Onto your quote. But if the wiring goes above 10 meter, per meter will cost you 30
# Sidratul Sadia: $3 that you need to pay up front on to my team.
# Jane: That's alright. It shouldn't be because the my hot water service in my electrical box are, like,not not even 5 meters away from each other. They're they're very close. It's only a
# Sidratul Sadia: Okay. It's
# Jane: okay, a fence separating them. So I'll have to get someone to take the fenceoff so he can have access to the um, the hot water the old hot water service.
# Sidratul Sadia: Okay. And, uh, no worries.
# Sidratul Sadia: We will see what happens tomorrow.
# Sidratul Sadia: And, yeah, we are going to take with the old system and replace
# Sidratul Sadia: the new one. And after all the work is done, my team is gonna give you a few
# Sidratul Sadia: documents. Please make sure to sign them back. So on tomorrow, which is 14th August,
# Sidratul Sadia: Wednesday, my team is gonna give you a call 30 or 40 minutes prior between
# Sidratul Sadia: 8 AM to 3 PM.
# Jane: Alright. No worries. Now I don't have to be there personally myselfCan one of my son sign the paperwork, or do I have to sign it?
# Sidratul Sadia: Uh, anyone can sign and attend it.
# Jane: Okay.No worries. Alright. Perfect.
# Sidratul Sadia: Yeah. Alright.
# Sidratul Sadia: Thank you.
# Sidratul Sadia: Thank you.
# Jane: Thank you. Thanks, Tina. Have a good day. Bye. Bye.
# Sidratul Sadia: Mhmm. You too. Bye.[/INST]
# Call Summary:
# 1. The address for installation is 6 Summercourt, Harness, Victoria 3337.
# 2. The house is a single-storey or double-storey.
# 3. The sooner the installation is done, the better.
# 4. Additional wiring beyond 10 meters will cost $3 per meter, payable upfront to Sidratul Sadia's team.
# 5. The hot water service and electrical box are less than 5 meters apart.
#
#
# </s>

# %%
data_preprocessed.set_format(type="torch")

# %%
MODEL_CHECKPOINT
# Out:
# 'mistralai/Mistral-7B-Instruct-v0.2'

# %%
# huggingface login
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_CHECKPOINT)
tokenizer.pad_token = tokenizer.unk_token
tokenizer.padding_side = 'right'
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# #Model finetuning

# %% [markdown]
# ##Preparing base model in 4bit quantization

# %%
#Prepare base model in 4bit quantization
compute_dtype = getattr(torch, "float16")
use_4bit = True

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)

# %%
#load our Mistral 7B base model as AutoModelForCausalLM
device_map = "auto"
model = AutoModelForCausalLM.from_pretrained(
    MODEL_CHECKPOINT,
    quantization_config=bnb_config,  # loading in 4-bit quantization
    device_map=device_map,
)
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
"""
updating model with the tokenizer pad_token_id as
defined earlier in order for both tokenizer and model stay synchronized in terms of special tokens they both use.
"""

# Configure the pad token in the base Mistral model
model.config.pad_token_id = tokenizer.pad_token_id

# %% [markdown]
# ##Prepare the fine-tuning model LoRA config

# %%
"""
From research papers : We find that the most critical LoRA hyperparameter is
how many LoRA adapters are used in total and that LoRA on all linear transformer block layers are required to match full finetuning performance".

"""
print(model)
# Out:
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32000, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): MistralRotaryEmbedding()
#         )
#         (mlp): MistralMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): MistralRMSNorm()
#         (post_attention_layernorm): MistralRMSNorm()
#       )
#     )
#     (norm): MistralRMSNorm()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
##So for Mistral 7B we select all the linear layers weights of the model for fine-tuning:

"""
q_proj,
k_proj,
v_proj,
o_proj,
gate_proj,
up_proj,
down_proj,
lm_head

"""
# Out:
# '\nq_proj,\nk_proj,\nv_proj,\no_proj,\ngate_proj,\nup_proj,\ndown_proj,\nlm_head\n\n'

# %%
# final LoRA configuration
#r is the rank of LoRA transformed matrices.
#golden rule that lora_alpha=2*r
"""
There is a golden rule that lora_alpha=2*r.
A good range specified to select r from - presented in original LoRA paper - is: 8, 16, 32, 64, 128, 256 or 512.
We select r=32 and lora_alpha=64 so we gain quite big memory usage reduction in the process.

"""
peft_config = LoraConfig(
        r=16,# earllier [32] :as reducing the r value in the LoRA configuration can help, as a smaller capacity model might generalize better with limited data.
        lora_alpha=32, #2r - golden rule
        lora_dropout=0.3, #[earlier 0.1] (increase it to introduce more regularization.)
        bias="none",
        task_type="CAUSAL_LM",
        target_modules=[
            "q_proj",
            "k_proj",
            "v_proj",
            "o_proj",
            "gate_proj",
            "up_proj",
            "down_proj",
            "lm_head",
        ],
    )

# %% [markdown]
# ##Model training

# %%
"""
If you can't increase the batch size due to memory constraints,
you can use gradient accumulation steps to effectively simulate a larger batch size without increasing memory usage.
For example, if you want an effective batch size of 8 but can only fit a batch size of 2 in memory, set gradient_accumulation_steps=4.

"""

from transformers import TrainingArguments
import time

run_name = "peft-dialogue-summary-training"
path = '/content/drive/MyDrive/finetune_sum/training_output'
output_dir = f'{path}/peft-dialogue-summary-training-{str(int(time.time()))}_train2'

training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=4,  # Increase batch size to stabilize training ##earlier [4]
    gradient_accumulation_steps=8,  # Adjusted to compensate for larger batch size, to reduce mem spike ##earlier [4]
    gradient_checkpointing=True,
    optim="paged_adamw_32bit",  # Memory-efficient optimizer
    save_steps=40,  # More frequent saving due to smaller dataset (It saves checkpoints)
    logging_steps=30,  # Log more frequently to monitor training closely
    learning_rate=5e-5,  # Slightly lower learning rate for more stable training ##Earlier [2e-4],
    fp16=True, ##deals with mixed-precsion training
    eval_strategy="epoch",
    eval_steps= 40,  # Evaluate more frequently due to small dataset ##earlier [100]
    max_grad_norm=0.3,
    num_train_epochs=6,  # Increase epochs to allow more thorough training ##Earlier = [5]
    weight_decay=0.1,  # Slightly higher weight decay to prevent overfitting.Ex of weight decay is L2 Regularization ##earlier = [0.01]
    warmup_steps=10,  # Shorter warmup due to fewer steps overall #earlier = [20]
    lr_scheduler_type="linear",
    run_name=run_name
)

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
trainer = SFTTrainer(
    model=model,
    train_dataset=data_preprocessed["train"],
    eval_dataset=data_preprocessed["validation"], # remove you have low VRAM and getting OOM errors
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=4096,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=False,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field, max_seq_length. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:283: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:321: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/2393 [00:00<?, ? examples/s]
# Map:   0%|          | 0/299 [00:00<?, ? examples/s]
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:482: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(**kwargs)

# %% [markdown]
# ##Start Training and save the adapter
#
#
# > Always monitor the validation loss and generalization gap (difference between training and validation loss) to guide your choice.
# Generalization Gap = Validation Loss - Training Loss
#
#
#
#
# * Small Generalization Gap: Indicates that the model is performing similarly on both the training and validation datasets, which generally suggests good generalization to unseen data.
#
# * Large Generalization Gap: Indicates that the model performs much better on the training data than on the validation data, suggesting overfitting. This means the model has learned patterns specific to the training data that don't generalize well to new data.
#   List item

# %%
#Always monitor the validation loss and generalization gap (difference between training and validation loss) to guide your choice.
trainer.train()
# Out:
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
#     <div>
#
#       <progress value='441' max='444' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [441/444 6:12:02 < 02:32, 0.02 it/s, Epoch 5.88/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.697700</td>
#       <td>1.624017</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.606800</td>
#       <td>1.576210</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.539600</td>
#       <td>1.562598</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.501600</td>
#       <td>1.557966</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.465500</td>
#       <td>1.558840</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# We detected that you are passing `past_key_values` as a tuple and this is deprecated and will be removed in v4.43. Please use an appropriate `Cache` class (https://huggingface.co/docs/transformers/v4.41.3/en/internal/generation_utils#transformers.Cache)
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# /usr/local/lib/python3.10/dist-packages/peft/utils/save_and_load.py:202: UserWarning: Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.
#   warnings.warn("Setting `save_embedding_layers` to `True` as embedding layers found in `target_modules`.")
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]

# %% [markdown]
# #####save final fine-tuned model (adapter)checkpoint for later use.

# %%
from time import strftime, localtime
path = '/content/drive/MyDrive/finetune_sum/final_adapter'
t = int(time.time()) ##in epoch
a = strftime('%Y-%m-%d %H:%M:%S', localtime(t)) #in datetime format
peft_model_path=f"{path}/peft-dialogue-summary-mistral-checkpoint-local-{a}_train2"

trainer.model.save_pretrained(peft_model_path)
tokenizer.save_pretrained(peft_model_path)

# %% [markdown]
# ##Models merging and saving

# %%
#The fine-tuned model is now trained but not yet ready to use for inference.
##fine-tuned model is an adapter model and the raw model (mistral 7b) a base model.

# %%
MODEL_CHECKPOINT
# Out:
# 'mistralai/Mistral-7B-Instruct-v0.2'

# %% [markdown]
# ###merging of adapter and base model and saving it

# %%
model = AutoModelForCausalLM.from_pretrained(MODEL_CHECKPOINT)

model = PeftModel.from_pretrained(model, peft_model_path)

model = model.merge_and_unload() ##merging of adapter and base model v0.2

# t = int(time.time()) ##in epoch
# a = strftime('%Y-%m-%d %H:%M:%S', localtime(t)) #in datetime format
path = '/content/drive/MyDrive/finetune_sum/merged_model'
model_dir = f"{path}/models/merged-peft-dialogue-summary-mistral_train2/"
model.save_pretrained(model_dir, safe_serialization=True)
tokenizer.save_pretrained(model_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ('/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2/tokenizer_config.json',
#  '/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2/special_tokens_map.json',
#  '/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2/tokenizer.model',
#  '/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2/added_tokens.json',
#  '/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2/tokenizer.json')

# %% [markdown]
# ##Load the final fine tuned model and tokenizer from the drive

# %%
MODEL_CHECKPOINT = 'mistralai/Mistral-7B-Instruct-v0.2'

# from time import strftime, localtime
path = '/content/drive/MyDrive/finetune_sum/final_adapter'
# t = int(time.time()) ##in epoch
# a = strftime('%Y-%m-%d %H:%M:%S', localtime(t)) #in datetime format
peft_model_path="/content/drive/MyDrive/finetune_sum/final_adapter/peft-dialogue-summary-mistral-checkpoint-local-2024-09-04 01:00:42_train2"

#pick the base model
model = AutoModelForCausalLM.from_pretrained(MODEL_CHECKPOINT)

#associate the base model with final adapter
model = PeftModel.from_pretrained(model, peft_model_path)

#merge both base model and adapter
model = model.merge_and_unload() ##merging of adapter and base model v0.2
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
from transformers import AutoTokenizer

# Path to the directory where the tokenizer is saved
tokenizer_dir = "/content/drive/MyDrive/finetune_sum/merged_model/models/merged-peft-dialogue-summary-mistral-2024-09-04 05:12:48_train2"

# Load the tokenizer from the saved directory
tokenizer = AutoTokenizer.from_pretrained(tokenizer_dir)

# %% [markdown]
# ##Pushing model to hugging face hub

# %%
#And now finally the fine-tuned model is both trained and ready to use for inference.
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
model.push_to_hub("Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3", private=True)
# Out:
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# Upload 6 LFS files:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.25G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/mlteam-justcall/Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3/commit/bed0324ebc490239c8154faeccbf13a26a78b9cf', commit_message='Upload MistralForCausalLM', commit_description='', oid='bed0324ebc490239c8154faeccbf13a26a78b9cf', pr_url=None, pr_revision=None, pr_num=None)

# %%
tokenizer.push_to_hub("Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3",private=True)
# Out:
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/mlteam-justcall/Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3/commit/1ea42078553b754e699718acaf17f8217ed802b4', commit_message='Upload tokenizer', commit_description='', oid='1ea42078553b754e699718acaf17f8217ed802b4', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# #Evaluation

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
##evaluate our fine-tuned dialogue summarization model against the original raw Mixtral 7B model
#ROUGE metric (metric dedicated for summarization task)
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ##Data preprocessing and inference

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from datasets import load_dataset,DatasetDict,load_metric

# Loading custom dataset
path = "/content/drive/MyDrive/finetune_sum/data/train2.csv"
dataset = load_dataset('csv', data_files= path)
# Split the dataset into train and test+validation sets
split_dataset = dataset['train'].train_test_split(test_size=0.2)
# Further split the test+validation set into validation and test sets
test_valid_split = split_dataset['test'].train_test_split(test_size=0.5)

# Combine splits into a single DatasetDict
data = DatasetDict({
    'train': split_dataset['train'],
    'validation': test_valid_split['train'],
    'test': test_valid_split['test']
})

# Example output
print(data)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 2393
#     })
#     validation: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 299
#     })
#     test: Dataset({
#         features: ['id', 'summary', 'dialogue'],
#         num_rows: 300
#     })
# })

# %%
data = data['test']

# %%
# data = data[:10]

# %%
data
# Out:
# Dataset({
#     features: ['id', 'summary', 'dialogue'],
#     num_rows: 300
# })

# %%
# Select the first 15 data points from the dataset
selected_data = data.select(range(15))

# Print the selected data points
print(selected_data)
# Out:
# Dataset({
#     features: ['id', 'summary', 'dialogue'],
#     num_rows: 15
# })

# %%
print(selected_data[0]["dialogue"])
# Out:
# System: CCO Pet Nutrition. How can I help you today?
# New JustCall: Hi there. I wonder if I could cancel, um, my subscription. I got one tubit, and I actually it didn't agree with my doggies.
# System: Okay. Yeah. Of course. Uh, let's have a look for you.
# New JustCall: SoI just realized that still I would have a subscription to come.
# System: Yeah. Of course. Let's have a look.
# New JustCall: I'm trying it, like, everysecond day or something, but they were quite sick. So
# System: Oh, bless them. Of course. Now okay. Let's have a look.
# System: Um, are you okay just to confirm your, um, address and postcode for me first, please?
# New JustCall: Yes. It's Moercroft, Old Fiskie Road,Ochterhaus Dundee. Delta delta 3 0 Romeo delta.
# System: That's great. Thank you. And can I just take your full name as well, please?
# New JustCall: It's on Gula York.
# System: That's great. Yeah. So you've got one, um,
# System: one top on the subscription. Um, so you just wanted to cancel that one.
# New JustCall: Yeah.
# System: Yeah. No worries. It's a lot.
# New JustCall: It's that other because the thing is it says 1 scoop, but my dogs are like,
# System: Hi.
# New JustCall: um, 1 3 kilos and 1 is 4 and a half kilos.Do you think it's just because it's too much? Or
# System: Um, so we do have a let me just double check. So you say 3
# System: 4a half?
# New JustCall: Mhmm.A quite small dogs. And it it just says give them a scoop each, but
# System: Yeah. It's 1 scoop a day with that. Yeah.
# System: I mean, you could you could lower the dosage and try it that way.
# New JustCall: Yeah. But it's, uh, like, it's up for every everysize of dog?
# System: No. So any anything up to 14 kilogram, we would say 1 scoop. Anything above
# System: that, so we'd say 15 to 23 kilograms, a scoop and a half.
# System: Anything over 23 kilogram, um, any dog over 23 kilogram, we would say 2
# New JustCall: Right. Okay.Yeah.
# System: scoops. So the big kinda the bigger the dog, the more we would say to give
# System: Um, you can reduce the the amount. I know a lot of people have done that where
# System: they give them half a scoop a day, um, and see how they get on with that that way.
# New JustCall: Mhmm.
# System: Um, so maybe maybe lower the dosage for them, see how they get on again if they are still too
# New JustCall: Yeah. I have to try that.And then I could just phone you back then. Yeah.
# System: yeah, if they're still they're still not happy with it, then, yeah, you've still got the money back guarantee as
# System: well. So like I say, if you do if you're still not happy with it, then you can just give us a call and we can get
# New JustCall: Okay.Then
# System: that sorted for you. But I'll cancel your subscription for now for you. And if that does does work, you can't.
# New JustCall: Thank you. And I'll do it. I'll I'll just lower the dose just now and see if that helps.
# System: Yeah. Yeah.
# New JustCall: It still gives them same benefits, so that's the thing.
# System: Yes. So this is you'll still see the same benefits. It might just take some
# New JustCall: Okay.
# System: longer to see. Yeah. Um, you can also so if you say if you feed
# System: twice in a day, you can also split the dose up. So maybe give them a
# New JustCall: Mhmm.
# System: a quarter of a scoop in the morning to quarter of a scoop in the night so they're not
# New JustCall: Okay.
# System: getting such a big dosage of it. Um, you could try that as well.
# New JustCall: Okay. I will do. Thank you for your help.
# System: No. That's alright. No worries at all. Thank you. Bye now. Bye.
# New JustCall: Okay. Bye now. Thanks.

# %%
print(selected_data[0]["summary"])
# Out:
# Call Summary:
# 1. The customer wants to cancel their subscription because the product didn't agree with their dogs.
# 2. The sales agent confirms the customer's address and name.
# 3. The customer asks about the dosage for their dogs and the sales agent provides the recommended dosage based on the dog's weight.
# 4. The sales agent suggests lowering the dosage and splitting it into two meals if necessary.
# 5. The customer agrees to try lowering the dosage and splitting it into two meals.
# 6. The sales agent cancels the customer's subscription and reminds them of the money-back guarantee.

# %%
len(selected_data)
# Out:
# 15

# %%
def preprocess_data(example):
  dialogue = example["dialogue"]
  prompt = f"""<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
{dialogue}[/INST]
</s>"""
  return {"dialogue": prompt}

# %%
data_preprocessed = selected_data.map(preprocess_data, batched=False, remove_columns=["id"])
# Out:
# Map:   0%|          | 0/15 [00:00<?, ? examples/s]

# %%
data_preprocessed
# Out:
# Dataset({
#     features: ['summary', 'dialogue'],
#     num_rows: 15
# })

# %%
print(data_preprocessed[3]["dialogue"])
# Out:
# <s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Amy: It's Bobby Arch. This is Ayesha speaking.
# Adam: Hi there. My name is Adam.Um, I'm just curious when your guys are coming back next.
# Amy: Okay.
# Amy: Sorry. Was this for
# Adam: So
# Amy: um, Adam?
# Adam: yes. That's the one. Yes. I've got the the water leak in my wall.
# Amy: Okay.
# Amy: Okay. So
# Amy: one of our technicians went out on the 6th for you.
# Adam: Yes. That's correct.
# Amy: Okay.
# Amy: Sorry. Sorry. Can you just explain to me what's, um,
# Amy: sorry.
# Adam: Sure. Sure. Um, so I had you guys come out, swap aaircon split system out for me, the process of doing that, you managed to there's some damage done inside the wall that's caused a water leak. That was confirmed by your guy that came out on 6th, and then he said he was gonna go back and have a discussion and then go from there. I was just I hadn't heard anything back yet, and I was curious when when we'll get this water leak fixed.
# Amy: Of course.
# Adam: Yeah.
# Amy: Okay. What I'm gonna do
# Adam: Yeah.
# Amy: is I'll just pop you on hold for a moment.
# Amy: So we
# Amy: Sorry. So we damaged the wall, and it caused a water leak. Is that correct?
# Adam: Butyeah. That's the short version. Yes.
# Amy: Okay. Um, alright. I'm gonna put pop you on hold for a moment, Adam.
# Adam: So
# Amy: Um, I'm I will try to get someone out for you as early as possible. Just bear with
# Amy: me. I won't be long. Okay?
# Amy: Thank you. Won't be long.
# Adam: Sure. Sure. Do you think?
# Amy: Thank you so much for holding, Adam.
# Adam: That's alright.
# Amy: Alright. So I've just, um,
# Amy: I did try to give Jesse a call, but I've just, um, apparently, he's gone home for the day.
# Adam: Mhmm.
# Amy: Um, so he's not in at the moment. So I wasn't able to get a hold of him, but I called my supervisor, Owen,
# Amy: Um, so he said
# Amy: um, he'll give you a call
# Adam: Yep.
# Amy: before 10:10 AM tomorrow morning to see what
# Adam: Sure.
# Amy: what's going on with this one, what we can do for you. Um, because I
# Amy: do believe he was trying to sort out another trade potentially, but
# Adam: Yes. Yes. I think so.
# Amy: yes. So he'll give you a call, um,
# Amy: in the morning, and I'll also make sure I follow-up with him and make sure he give
# Amy: you a call. So I'll personally follow that one up for you as well.
# Adam: Yep. No. That's fine. I'm just glad he's gonna call me back.
# Amy: No. No worries. I'll
# Amy: your call. It'd be before 10. Um, if not, just give the office a call and just let
# Amy: them know that, um, you're just waiting to hear from Owen.
# Adam: Sure. I can do that. No worries at all.
# Amy: Okay. Thank you so much for understanding, Adam.
# Adam: No. That's all good. Thanks for your help.
# Amy: No worries. Bye.
# Adam: Alright. Bye.[/INST]
# </s>

# %%
print(data_preprocessed[3]["summary"])
# Out:
# Call Summary:
# 1. Ayesha reported a water leak in her wall and asked when the repair will be done.
# 2. Amy tried to contact Jesse, but he had already left for the day.
# 3. Jesse will call Ayesha before 10:10 AM tomorrow to discuss the repair options.
# 4. Adam expressed relief that Jesse will be calling back soon.

# %% [markdown]
# ##Load models from Hugging Face hub along with the respective tokenizers.

# %%
# Fine-tuned model ##RAM USED max (40GB plus)
tokenizer = AutoTokenizer.from_pretrained("mlteam-justcall/Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3")
model = AutoModelForCausalLM.from_pretrained("mlteam-justcall/Mistral-7B-Instruct-v0.2-SAASLABS-SFTT-v3")
model.generation_config.pad_token_id = model.generation_config.eos_token_id
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:81: UserWarning:
# Access to the secret `HF_TOKEN` has not been granted on this notebook.
# You will not be requested again.
# Please restart the session if you want to be prompted again.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.21k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/652 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/6 [00:00<?, ?it/s]
# model-00001-of-00006.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00006.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00003-of-00006.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00004-of-00006.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00005-of-00006.safetensors:   0%|          | 0.00/4.83G [00:00<?, ?B/s]
# model-00006-of-00006.safetensors:   0%|          | 0.00/4.25G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %%
# Base Mistral-7B-Instruct-v0.2 model
raw_tokenizer = AutoTokenizer.from_pretrained('mistralai/Mistral-7B-Instruct-v0.2')
raw_model = AutoModelForCausalLM.from_pretrained('mistralai/Mistral-7B-Instruct-v0.2')
raw_model.generation_config.pad_token_id = raw_model.generation_config.eos_token_id
raw_tokenizer.pad_token = raw_tokenizer.unk_token
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:99: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]

# %% [markdown]
# ##Print of one example of full dialogue, groundtruth summary and summaries generated by both models.

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### rough test

# %%
def summarize(tokenizer, model, dialogue):
    inputs = tokenizer(dialogue, return_tensors="pt").to(DEVICE)
    inputs_length = len(inputs["input_ids"][0])
    with torch.inference_mode():
        outputs = model.generate(**inputs, max_new_tokens=256, do_sample=True, temperature=0.0001)
    return tokenizer.decode(outputs[0][inputs_length:], skip_special_tokens=True)

# %%
dialogue = """<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
Luke: Hello. Luke from Mandeep speaking.
Alessio: Hi, Rick. How's it going? Uh, just returning this call.
Luke: Oh, yeah. Is this Alessio?
Alessio: Uh, yes. Speaking.
Luke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base
Luke: mate. Um, we haven't spoken in a while.
Luke: Wanted to see how everything was going on your end.
Alessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link?
Luke: A link.
Luke: What's lates and things?
Alessio: Yeah.
Luke: Yeah. So we we don't actually use a a link
Luke: for, like, uh, referrals or anything. We I mainly do it through email or just
Luke: uh, via
Alessio: Okay.
Luke: via calling, um, because we kinda
Luke: we we think that speeds up the process a lot rather than, uh,
Luke: actually providing a link like the other unsecured lenders.
Luke: Um, were you doing much in that space at the moment, mate?
Alessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in?
Luke: We we we can do some white label marketing for you, mate.
Luke: Um, would that would that be better?
Alessio: What what does that sort of, um, entail?
Luke: So that's like, um, it'll be like a marketing
Luke: piece, um, just promoting small businesses.
Luke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.
Alessio: Okay.
Luke: Um, I can send you I can send you a draft.
Alessio: Yeah. Okay. Is it just like a landing page type thing or
Luke: Yeah. Yeah. Yeah.
Alessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.
Luke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.
Alessio: Yeah. No problem.
Luke: Alright. Thanks, mate.
Alessio: Alright. Thanks. Goodbye.[/INST]
</s>
"""
prompt = f"""<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
{dialogue}[/INST]
</s>"""

# %%
dialogue
# Out:
# "<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>\n"

# %%
(f"dialog:{dialogue}\n\nfinetuned_summ: {summarize(tokenizer, model.to(DEVICE), dialogue)}")
# Out:
# "dialog:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>\n\n\nfinetuned_summ: Call Summary:\n1. Luke from Mandeep speaking.com called Alessio from OnDeck to touch base and check how things are going.\n2. Alessio mentioned that he doesn't remember their last conversation but asked if Luke had a chat with his team about functionality for a referral link.\n3. Luke explained that they don't use a link for referrals and mainly do it through email or calling.\n4. Alessio mentioned growing his content on the website for finance related resources for small businesses and asked if Luke had any forms or anything to integrate.\n5. Luke offered to send a white label marketing piece promoting small businesses for Alessio to share.\n6. Alessio agreed to receive the draft and thanked Luke.\n\n\n"

# %%
(f"dialog:{dialogue}\n\nBasemodel_summ: {summarize(raw_tokenizer, raw_model.to(DEVICE), dialogue)}")
# Out:
# "dialog:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>\n\n\nBasemodel_summ: Luke, from OnDeck, called Alessio to check in and see how things were going. Alessio mentioned they had spoken before, but Luke couldn't remember when. Luke explained that OnDeck doesn't use referral links for their business and instead uses email or direct calls for referrals. Alessio was interested in using a link for finance-related resources on his website for small businesses and asked if OnDeck had any forms or marketing materials that could be integrated. Luke offered to create a white label marketing piece for Alessio, which would be a landing page that Alessio could customize with his logo and share with his audience. Alessio agreed and asked for a draft to be sent to him. Luke promised to send it over and asked for Alessio's feedback. The call ended with both parties expressing thanks and goodbyes."

# %%
idx = 2
(f"dialo: {data_preprocessed['dialogue'][idx]}\n\n summ: {summarize(tokenizer, model.to(DEVICE), data_preprocessed['dialogue'][idx])}")
# Out:
# "dialo: <s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\n\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>\n\n summ: INSTINST:\n\n\n"

# %% [markdown]
# ### Real test

# %%
def summarize(tokenizer, model, dialogue):
    inputs = tokenizer(dialogue, return_tensors="pt").to(DEVICE)
    inputs_length = len(inputs["input_ids"][0])
    with torch.inference_mode():
        outputs = model.generate(**inputs, max_new_tokens=256, do_sample=True, temperature=0.0001)
    return tokenizer.decode(outputs[0][inputs_length:], skip_special_tokens=True)

# %%
# import os
# import torch

# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# batch_size = 10  # Adjust based on your memory constraints
# finetuned_generated_summaries = []

# for i in range(0, len(data_preprocessed["dialogue"]), batch_size):
#     batch = data_preprocessed["dialogue"][i:i+batch_size]
#     print(f"{i}th batch", batch)

#     for row in batch:
#         print(row)
#         finetuned_generated_summary = summarize(tokenizer, model.to(DEVICE), row).strip()
#         finetuned_generated_summaries.append(finetuned_generated_summary)

#     torch.cuda.empty_cache()
#After processing each batch, the GPU memory is cleared using torch.cuda.empty_cache() to prevent out-of-memory errors.


import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
finetuned_generated_summaries = []
for idx, row in enumerate(data_preprocessed["dialogue"]):
  finetuned_generated_summary = summarize(tokenizer, model.to(DEVICE), row).strip() ##use of GPU (max 34.7GB )
  finetuned_generated_summaries.append(finetuned_generated_summary)

# %%
data_preprocessed["dialogue"][2]
# Out:
# "<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\n\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>"

# %%
# for idx, row in enumerate(data_preprocessed["dialogue"]):
idx = 2
row = data_preprocessed["dialogue"][idx]
finetuned_generated_summary = summarize(tokenizer, model.to(DEVICE), row).strip()

# %%
(f"dialo: {data_preprocessed['dialogue'][idx]}\n\n summ: {summarize(tokenizer, model.to(DEVICE), row)}")
# Out:
# "dialo: <s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:\n\nLuke: Hello. Luke from Mandeep speaking.\nAlessio: Hi, Rick. How's it going? Uh, just returning this call.\nLuke: Oh, yeah. Is this Alessio?\nAlessio: Uh, yes. Speaking.\nLuke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base\nLuke: mate. Um, we haven't spoken in a while.\nLuke: Wanted to see how everything was going on your end.\nAlessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link? \nLuke: A link.\nLuke: What's lates and things?\nAlessio: Yeah.\nLuke: Yeah. So we we don't actually use a a link\nLuke: for, like, uh, referrals or anything. We I mainly do it through email or just\nLuke: uh, via\nAlessio: Okay.\nLuke: via calling, um, because we kinda\nLuke: we we think that speeds up the process a lot rather than, uh,\nLuke: actually providing a link like the other unsecured lenders.\nLuke: Um, were you doing much in that space at the moment, mate?\nAlessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in? \nLuke: We we we can do some white label marketing for you, mate.\nLuke: Um, would that would that be better?\nAlessio: What what does that sort of, um, entail?\nLuke: So that's like, um, it'll be like a marketing\nLuke: piece, um, just promoting small businesses.\nLuke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.\nAlessio: Okay.\nLuke: Um, I can send you I can send you a draft.\nAlessio: Yeah. Okay. Is it just like a landing page type thing or\nLuke: Yeah. Yeah. Yeah.\nAlessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.\nLuke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.\nAlessio: Yeah. No problem.\nLuke: Alright. Thanks, mate.\nAlessio: Alright. Thanks. Goodbye.[/INST]\n</s>\n\n summ: INSTINST:\n\n\n"

# %%
finetuned_generated_summary
# Out:
# 'INSTINST:\n\n\n'

# %%
for idx, row in enumerate(data_preprocessed["dialogue"]):
  print(f"row{idx} and the row is:{row}")
  print("****************************************************************")
# Out:
# row0 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# System: CCO Pet Nutrition. How can I help you today?
# New JustCall: Hi there. I wonder if I could cancel, um, my subscription. I got one tubit, and I actually it didn't agree with my doggies.
# System: Okay. Yeah. Of course. Uh, let's have a look for you.
# New JustCall: SoI just realized that still I would have a subscription to come.
# System: Yeah. Of course. Let's have a look.
# New JustCall: I'm trying it, like, everysecond day or something, but they were quite sick. So
# System: Oh, bless them. Of course. Now okay. Let's have a look.
# System: Um, are you okay just to confirm your, um, address and postcode for me first, please?
# New JustCall: Yes. It's Moercroft, Old Fiskie Road,Ochterhaus Dundee. Delta delta 3 0 Romeo delta.
# System: That's great. Thank you. And can I just take your full name as well, please?
# New JustCall: It's on Gula York.
# System: That's great. Yeah. So you've got one, um,
# System: one top on the subscription. Um, so you just wanted to cancel that one.
# New JustCall: Yeah.
# System: Yeah. No worries. It's a lot.
# New JustCall: It's that other because the thing is it says 1 scoop, but my dogs are like,
# System: Hi.
# New JustCall: um, 1 3 kilos and 1 is 4 and a half kilos.Do you think it's just because it's too much? Or
# System: Um, so we do have a let me just double check. So you say 3
# System: 4a half?
# New JustCall: Mhmm.A quite small dogs. And it it just says give them a scoop each, but
# System: Yeah. It's 1 scoop a day with that. Yeah.
# System: I mean, you could you could lower the dosage and try it that way.
# New JustCall: Yeah. But it's, uh, like, it's up for every everysize of dog?
# System: No. So any anything up to 14 kilogram, we would say 1 scoop. Anything above
# System: that, so we'd say 15 to 23 kilograms, a scoop and a half.
# System: Anything over 23 kilogram, um, any dog over 23 kilogram, we would say 2
# New JustCall: Right. Okay.Yeah.
# System: scoops. So the big kinda the bigger the dog, the more we would say to give
# System: Um, you can reduce the the amount. I know a lot of people have done that where
# System: they give them half a scoop a day, um, and see how they get on with that that way.
# New JustCall: Mhmm.
# System: Um, so maybe maybe lower the dosage for them, see how they get on again if they are still too
# New JustCall: Yeah. I have to try that.And then I could just phone you back then. Yeah.
# System: yeah, if they're still they're still not happy with it, then, yeah, you've still got the money back guarantee as
# System: well. So like I say, if you do if you're still not happy with it, then you can just give us a call and we can get
# New JustCall: Okay.Then
# System: that sorted for you. But I'll cancel your subscription for now for you. And if that does does work, you can't.
# New JustCall: Thank you. And I'll do it. I'll I'll just lower the dose just now and see if that helps.
# System: Yeah. Yeah.
# New JustCall: It still gives them same benefits, so that's the thing.
# System: Yes. So this is you'll still see the same benefits. It might just take some
# New JustCall: Okay.
# System: longer to see. Yeah. Um, you can also so if you say if you feed
# System: twice in a day, you can also split the dose up. So maybe give them a
# New JustCall: Mhmm.
# System: a quarter of a scoop in the morning to quarter of a scoop in the night so they're not
# New JustCall: Okay.
# System: getting such a big dosage of it. Um, you could try that as well.
# New JustCall: Okay. I will do. Thank you for your help.
# System: No. That's alright. No worries at all. Thank you. Bye now. Bye.
# New JustCall: Okay. Bye now. Thanks.[/INST]
# </s>
# ****************************************************************
# row1 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Morgan: Hey,
# Richard: Hello.
# Morgan: Hello there, Richard. How's it going?
# Richard: Not too bad.
# Morgan: Right on. Right on. Hey. I, uh, I just seen you called, and then I know we'rea little bit back. Of course, I figured I'd give you a ring and kinda clear the air a little bit here. But, uh, I, uh, I I first off, I mean, I apologize for reaching out to you, Richard, like that. Obviously, probably super annoying getting text messages for somebody that's not you. I do apologize for that. Um, I was actually just reaching out to a past client of mine. I don't know. Maybe I can help you instead. Maybe I can I'm, you know, hard way to scratch here, Richard. But, uh, you know, I was actually reaching out to to Lois there just to kind of explain a little bit of our credit restobstruction program and an exclusive low interest rate program we got going on right now. Um, to help our clients save, you know, 100 of dollars a month on their auto loan payments. After COVID, they were just through the roof. Um, but also helping people get into a little bit newer newer, nicer vehicle. As well for, you know, more affordable payment. I don't know if I can even help you, Richard, or maybe I'm just taking up too much of your time here, but maybe I can. Is is there anything about your current vehicle situation that, you know, you wish you could
# Richard: I'm going through a, uh,
# Richard: customer proposal right now with Jay Button.
# Richard: Through Clean Start.
# Morgan: Okay. Oh, no kidding. That's, uh,that's actually our our partnerships. How how did you end up getting set up with with with CleanStar? Maybe you're working with another another representative of our company?
# Richard: Actually, it's probably through one of your associates to, uh, their it would be with
# Richard: Tom,
# Richard: What is it? Jamie?
# Morgan: Is it with a Jesse?
# Richard: Just
# Richard: With Jesse. Yes.
# Morgan: I see it. I hear that all the time. He's amazing.Amazing. I hope he's treating you guys good. Right?
# Richard: Yeah. Right now, I'm just
# Richard: trying to get everything dealt with through Clean Start, and we have to wait
# Morgan: Yeah. Yeah.
# Richard: 45 days or until Clean Start gets it into my credit report, then he can actually
# Richard: go and get that vehicle for me.
# Morgan: Right?There's also another way that maybe he might have missed or didn't explain, um, there is the the possibility of going on our credit reference program as well. Did he explain that to you at all?
# Richard: Yeah. I've already done that, and, uh, the
# Richard: and mom's already got her
# Richard: her credit in with mine joined together. That's why we're 90 95
# Richard: percent with the bank right now.
# Morgan: I see. Nice.Well, then you know what? You might have some good news coming down the line sooner than you think. What was your last name, Richard? Maybe I could take a look at it for you and just kinda help push this along the line
# Richard: It's
# Morgan: speed things up or or whatever I can do to help Jesse out.
# Richard: it's Hogan, and, yeah, you you talked to me on Tuesday. That's why the
# Morgan: I thought that's right.
# Richard: number was familiar.
# Morgan: I thought so. I don't know how this how I didn't
# Richard: No.
# Morgan: change yours. So you're not a Lois Nelson.Alright. So you said your last name is Hogan. Right?
# Richard: H o g a n. Yeah.
# Morgan: H o g n.
# Richard: No, Jesse. You did not. I've already had to resign paperwork
# Richard: with Clean Start again. So I told Jesse I left Jesse, I think, a day or 2
# Richard: to, uh, require that paperwork because I had to resign different paperwork. So
# Richard: let him know to go require that. Because even though he's got it in his hand,
# Morgan: Yeah. You were saying that
# Richard: bank wants a seat on my credit report.
# Richard: Yeah.
# Morgan: you were saying that, uh, no problem.
# Richard: So we're just waiting on that part there. So when they
# Richard: we can get rid of this vehicle and get me into a proper one and to a better
# Morgan: Yep.
# Richard: loan. And not only that, clean starts getting rid of some of my shit from my ex
# Morgan: I know.
# Richard: that on my credit report. Plus they're also taking a 10 trailer that I that's
# Richard: should've been gone last year.
# Richard: But I got screwed on that. So they're coming to get that too.
# Richard: And get it right out of my name and get rid of it. And Jesse's getting me out of these high paint
# Richard: high interest pay and payments.
# Morgan: Beautiful.Yeah.
# Richard: Is what he's doing through Clean Start. So
# Richard: I
# Richard: Yeah.
# Morgan: He's great. He's great. I'll I'll leave it to you guys. I'm gonna textnow that I know your last name, Richard. I also updated this so I don't ever text you as Lois ever again. So we'll make sure that doesn't happen. I hope your wife's name isn't Lois as well. Like, that might get you into a trick
# Richard: Nope. Nope.
# Morgan: tricky situation. I don't know. She's gonna be like, who's this Lois person you're talking to, Rich?So I don't wanna get you in trouble with her. But, uh, but I'll let you guys enjoy the rest of your night, and you have a a wonderful night, guys. I will touch base with Jesse as well. Let him know that I've spoken with you guys.
# Richard: Yeah.
# Morgan: And to and to hurry it up a little bit. Who knows? Maybe get some exceptions to get this done for you guys sooner than you
# Richard: Yeah. Well, hold we're just waiting on, like, Jesse said. He's just he even knows he's
# Richard: got the paperwork in hand, the banks out there says, well, we don't care about the paperwork. We wanna see it on his credit report.
# Morgan: Mhmm. Yep. Yep.Yep.
# Richard: So I had 2 phone I had the phone
# Richard: clean start, and they sent me new paperwork to sign, and they said they were sending it off
# Richard: right away to, uh, Equifax and that shit.
# Richard: So at least then, uh, it would get there and
# Richard: and I said, yeah. Well, I told them straight out the bank's not gonna touch me till they see it.
# Morgan: Right.Right. Yeah. That's fine. It happens. Yeah.
# Richard: And she kinda understood. She goes, yeah. I've seen those situations before.
# Morgan: Yeah.
# Richard: Some banks will take the paperwork and say, okay. Let's get
# Morgan: Yeah. It's it's
# Richard: started on this. And then she says, you're of course, the one bank, he she says it's one of the ones that won
# Richard: see everything.
# Morgan: yeah. It's more so a little bit higher of a risk.
# Richard: Yeah.
# Morgan: Right, Richard? So, you know, you you're just a little bit higher risk.
# Richard: Yeah.
# Morgan: But Jesse's gonna do everything that you need, uh, to put you in the bestapproval and stuff like that. So
# Richard: Yeah.
# Morgan: um, that's great. And and you know what? Just go ahead and save my number downtoo, Richard. If you ever need it, I mean, and Jesse's not answering or something, you can always give me his call as well. You know, Jesse and I have worked together for many, many years. He's in Calgary. I'm out in in Vancouver, so we're kind of all over the place.
# Richard: Yeah.
# Morgan: Um, but, uh, but I will make sure that we get that corrected for you right now for you.
# Richard: What was your full name again?
# Morgan: My full name is Morgan Kennedy, my friend.
# Richard: Okay.
# Richard: Okay.
# Richard: I'm just writing that down.
# Richard: So that way, it's there
# Morgan: Yeah. That way, you know, at least you
# Richard: so I know exactly who's
# Morgan: youmean, you gotta it's not like everyday you're getting a a 587 number reach out to you
# Richard: No. It's I I've seen the number.
# Morgan: too. I'm sure, Richard. Right? So I'm sure that's why it was familiar for you.
# Richard: I saw the number, and it's like, I know that freaking number. I'm not quite sure, but I
# Richard: seen that number, and it's got me confused.
# Morgan: Yeah. Well, I guess, uh, I'll I'll throw I'll justpoint it out at this point. It I knew the whole time you're Richard, I just enjoyed talking to you so much last time. I figured I'd try it again this time and see where it goes. But, uh, no. I'm just bugging you. But, anyway, Richard, enjoy the rest of your night, my friend, and and, uh, maybe, who knows? We'll chat with you again next week on Monday and hopefully, I got the name right again.
# Richard: Yeah. Well, hopefully, everything that works out here and get us everything gets
# Morgan: Yeah. Yeah.
# Richard: kicked in the butt here a little bit quicker because I hate this looping around shit.
# Morgan: Well, I'll put the fire under Jesse Josh, and thenif I have to fly down to Calgary to kick it for you, I'll do that too. But
# Richard: Yeah.
# Morgan: What I'll I'll I'll just look at so what did he say about your your credit reference, your mom?
# Richard: With my mom, sure. Well, with
# Richard: uh, mom's got good credit.
# Morgan: K.
# Richard: Really good credit. And then we what we did is we
# Richard: we joined hers with mine for the bank to give me a higher credit
# Richard: credit score.
# Richard: So but everything is on that part.
# Morgan: Your mom is your mom's nameis your mom's name Angeline? Angeline?
# Richard: Yes. It is.
# Morgan: I see your guys' stuff here.
# Richard: Yeah.
# Morgan: That's good.
# Richard: She won't cosign. She won't do anything because
# Morgan: Right.
# Richard: of course, she's retired and everything else. Right? So is dad.
# Richard: She won't cosign. She won't do anything, but she was willing to join her credit
# Richard: with my credit to help me get into the other vehicle a lot quicker.
# Richard: What we were doing.
# Morgan: Yeah.Yeah.
# Richard: And the bank is actually the one that offered that.
# Morgan: Yeah. I see that here. I couldsee that that's what the bank are looking
# Richard: And Jesse and when Jesse got involved after, uh, the one
# Richard: guy that I was Dennis when I was dealing with Dennis, he said, Jesse's gonna take over
# Morgan: Yep.
# Richard: because he's got more report with the banks and everything else. He's better at it than he is.
# Morgan: Yep.
# Richard: And I I told Jess. Yes. Because I don't know what the problem with the bank is. They're
# Richard: one that's, uh, actually suggested it. Now they wanna play these games.
# Morgan: Alright.
# Richard: So I said to they're the ones that did it.
# Richard: They're the ones that I said they have to, uh,
# Richard: actually accept it no matter how they look at it. They're the ones that, uh,
# Richard: brought it up, and they wanted to do this for me to get into loan.
# Richard: Well, guess what? Now you're gonna honor it.
# Richard: So
# Morgan: Yep. Well, then there you go.
# Richard: that's what I had to make phone calls tomorrow, and I had to explain it to her, and I had
# Richard: Dennis to explain it to her. And that's why she said, yeah. Long as I'm not
# Richard: cosigning, my name doesn't go anywhere near or on any paperwork.
# Richard: I I will give
# Richard: my
# Richard: I will do it for my credit score to join on with his, and that's it.
# Morgan: Alright. Alright.
# Richard: And Dennis said so Dennis tried, so did Jesse, and I already
# Richard: pulled him straight out. You know what? My mom's gonna say, she's gonna tell you where to put it and how to get there with that part.
# Richard: So don't even ask her for a, uh, cosign.
# Richard: I I already warned them.
# Morgan: Mhmm. Oh, and you know what? That's exact that's exactly why
# Richard: Yeah.
# Morgan: we designed our credit reference program to help
# Richard: Yeah.
# Richard: Yeah.
# Morgan: people in that situation. So it's great that we have that option for you.
# Richard: Yeah.
# Morgan: And, uh, and that's great, man. I look forward to seeing how we can help you as a company
# Richard: So yeah. Well,
# Richard: I
# Morgan: Jesse's gonna take good care of you. I know that.
# Richard: Yeah. Well, like I said to Jesse, I said, soon this goes through, they can actually
# Richard: see it, they can actually honor that because they have no choice because they're the ones that's
# Richard: that, uh, put it through and said we'll join the 2 and get a a better credit
# Richard: score, and we'll give you the loan. Well, guess what? Now you're gonna honor that and
# Richard: Soon as you see that and me going through clean and start getting everything else out of my name,
# Richard: I just owe $15,000, and that's it.
# Morgan: That's amazing. Good for you. Good for you, Richard.
# Richard: To put break yeah.
# Richard: So it's like
# Morgan: That's amazing stuff. That's an amazing program. I know it's it'sit's great to help people. I'm happy that it work in. I look forward to seeing what they do help you out here.
# Richard: Wow.
# Richard: When I'm looking when I'm looking basically between 60 to 80 fucking grand
# Richard: yeah, it's it was, uh, a big eye opener when I seen some of
# Richard: shit, and it was from my ex.
# Morgan: Unbelievable.
# Richard: And one part wise, it's not
# Richard: yeah. So I decided and went, hey, Jesse. What can we do
# Richard: he told me about cleaning, started here, and he explained it. So I
# Richard: had them pull me up, and they explained it a little bit more to me. So
# Richard: like, okay. It's this isn't just some screw up. You guys are actually
# Richard: working with government, and they're like, yeah. We do.
# Richard: So but
# Richard: uh, I'm getting phone calls left, right, and center here from
# Richard: from Santana right now, and I'm already pissed off with them. And I already told them, here's the
# Richard: information.
# Richard: I'm gonna take further action.
# Morgan: Yep. Well, very good.
# Richard: Because right now, they can't even they right now, as we speak, they it's already on
# Richard: on, uh, with Clean Start. They can't even touch that car.
# Richard: So because I can hold damn well.
# Morgan: Yeah. Well, that's right. They yeah. Well, you
# Richard: Yep.
# Morgan: and they're it's there to help people, like I said, Richard. But, hey, I'm gonna let you go here for now, boss.It's great chatting with you again. And, uh, and, again, you know, we'll get it done for you. Don't don't worry about that. But I got everything corrected here. So
# Richard: Yeah.
# Morgan: don't have to worry about me reaching out to you here for from now on.
# Richard: No. That's not not a problem. It's just I know I recognize the numbers. So you just click one
# Morgan: Yeah.
# Richard: the hell? Hold on a minute. I know I've seen that number before. Is that one of the companies I have
# Richard: applied to down in Alberta, or is it
# Morgan: Uh, no. No.
# Richard: and then or is it
# Richard: Yeah. You're downtown Vancouver.
# Morgan: I'm actually downtown Vancouver here. Uh, I'm I'm right downtown, butI'm originally from Edmonton. And and then I was yeah,
# Richard: Yeah. That's why the number came up for Edmonton I thought
# Richard: shit. It's not one of the companies that I just applied to.
# Morgan: Yeah. I know.
# Richard: Yeah.
# Morgan: Like I said, right, me and Jesse have known each other for for years. We've worked together for years.And, uh, and I ended up moving out to Vancouver, but, you know,
# Richard: Yeah.
# Morgan: I got rid of my number, then I you lose all that past clientele and all that other stuff. So
# Richard: Yeah.
# Morgan: that's, uh, that's the biggest thing. So, anyway, I'm out in Vancouver with an Albertanumber. But, uh, anyway, like I said, Richard, enjoy your night, boss. I will, uh, maybe I'll chat with you soon, but but I'll leave it into Jesse's hand, and I'm sure he'll get it done for you.
# Richard: Yeah. Not a
# Richard: problem. Well, have yourself a good day.
# Morgan: Hey. You as well, my friend. Cheers.
# Richard: Yeah. Okay. Bye.[/INST]
# </s>
# ****************************************************************
# row2 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Luke: Hello. Luke from Mandeep speaking.
# Alessio: Hi, Rick. How's it going? Uh, just returning this call.
# Luke: Oh, yeah. Is this Alessio?
# Alessio: Uh, yes. Speaking.
# Luke: Hey, Alejandro. Um, yeah, mate. Luke from OnDeck here. I was just, uh, calling to touch base
# Luke: mate. Um, we haven't spoken in a while.
# Luke: Wanted to see how everything was going on your end.
# Alessio: Yeah. No. Thanks for that. Um, yeah. Going well. Um, Idon't remember. I think we spoke a while back, but, um, did you end up having a chat with your team to see if you had any functionality for, like, a link? What's the referral a referral link?
# Luke: A link.
# Luke: What's lates and things?
# Alessio: Yeah.
# Luke: Yeah. So we we don't actually use a a link
# Luke: for, like, uh, referrals or anything. We I mainly do it through email or just
# Luke: uh, via
# Alessio: Okay.
# Luke: via calling, um, because we kinda
# Luke: we we think that speeds up the process a lot rather than, uh,
# Luke: actually providing a link like the other unsecured lenders.
# Luke: Um, were you doing much in that space at the moment, mate?
# Alessio: Yeah. I'm doing a bit in that space, and I'm looking at, um,growing a bit more on the content side on on our website for finance related resources for small businesses. Um, so it'd be something that'd be handy we can put that link in there and, um, just make it easier for people to sign up. But, um, do you have any, like, forms or anything like that that I can integrate in?
# Luke: We we we can do some white label marketing for you, mate.
# Luke: Um, would that would that be better?
# Alessio: What what does that sort of, um, entail?
# Luke: So that's like, um, it'll be like a marketing
# Luke: piece, um, just promoting small businesses.
# Luke: And all you need to do is just put your logo on it, and then you can share that kind of how you like.
# Alessio: Okay.
# Luke: Um, I can send you I can send you a draft.
# Alessio: Yeah. Okay. Is it just like a landing page type thing or
# Luke: Yeah. Yeah. Yeah.
# Alessio: Yep. Okay. Yeah. If you can send through that, that'd be that'd be great. Yeah.
# Luke: For sure, mate. For sure. Well, I'll send that through to you now. Let me know what you think.
# Alessio: Yeah. No problem.
# Luke: Alright. Thanks, mate.
# Alessio: Alright. Thanks. Goodbye.[/INST]
# </s>
# ****************************************************************
# row3 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Amy: It's Bobby Arch. This is Ayesha speaking.
# Adam: Hi there. My name is Adam.Um, I'm just curious when your guys are coming back next.
# Amy: Okay.
# Amy: Sorry. Was this for
# Adam: So
# Amy: um, Adam?
# Adam: yes. That's the one. Yes. I've got the the water leak in my wall.
# Amy: Okay.
# Amy: Okay. So
# Amy: one of our technicians went out on the 6th for you.
# Adam: Yes. That's correct.
# Amy: Okay.
# Amy: Sorry. Sorry. Can you just explain to me what's, um,
# Amy: sorry.
# Adam: Sure. Sure. Um, so I had you guys come out, swap aaircon split system out for me, the process of doing that, you managed to there's some damage done inside the wall that's caused a water leak. That was confirmed by your guy that came out on 6th, and then he said he was gonna go back and have a discussion and then go from there. I was just I hadn't heard anything back yet, and I was curious when when we'll get this water leak fixed.
# Amy: Of course.
# Adam: Yeah.
# Amy: Okay. What I'm gonna do
# Adam: Yeah.
# Amy: is I'll just pop you on hold for a moment.
# Amy: So we
# Amy: Sorry. So we damaged the wall, and it caused a water leak. Is that correct?
# Adam: Butyeah. That's the short version. Yes.
# Amy: Okay. Um, alright. I'm gonna put pop you on hold for a moment, Adam.
# Adam: So
# Amy: Um, I'm I will try to get someone out for you as early as possible. Just bear with
# Amy: me. I won't be long. Okay?
# Amy: Thank you. Won't be long.
# Adam: Sure. Sure. Do you think?
# Amy: Thank you so much for holding, Adam.
# Adam: That's alright.
# Amy: Alright. So I've just, um,
# Amy: I did try to give Jesse a call, but I've just, um, apparently, he's gone home for the day.
# Adam: Mhmm.
# Amy: Um, so he's not in at the moment. So I wasn't able to get a hold of him, but I called my supervisor, Owen,
# Amy: Um, so he said
# Amy: um, he'll give you a call
# Adam: Yep.
# Amy: before 10:10 AM tomorrow morning to see what
# Adam: Sure.
# Amy: what's going on with this one, what we can do for you. Um, because I
# Amy: do believe he was trying to sort out another trade potentially, but
# Adam: Yes. Yes. I think so.
# Amy: yes. So he'll give you a call, um,
# Amy: in the morning, and I'll also make sure I follow-up with him and make sure he give
# Amy: you a call. So I'll personally follow that one up for you as well.
# Adam: Yep. No. That's fine. I'm just glad he's gonna call me back.
# Amy: No. No worries. I'll
# Amy: your call. It'd be before 10. Um, if not, just give the office a call and just let
# Amy: them know that, um, you're just waiting to hear from Owen.
# Adam: Sure. I can do that. No worries at all.
# Amy: Okay. Thank you so much for understanding, Adam.
# Adam: No. That's all good. Thanks for your help.
# Amy: No worries. Bye.
# Adam: Alright. Bye.[/INST]
# </s>
# ****************************************************************
# row4 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# VIJAYA: Hello?
# Mohammed Khaled: Hello? Uh, hi. Uh, good morning. Jay, Mohammed here. Mohammed,is signing. Eric does. It's a month for signing that you probably use.
# VIJAYA: Hello. Hello. Moment by. Hello?
# Mohammed Khaled: Alright. Hi. I am so sorry if I missed.Meet a basically hard connection, so I was going to reconsider the stuff. So I was working Yeah. I just I just I just I
# VIJAYA: Yeah. Yeah.
# Mohammed Khaled: yes. It it is. It is a beautiful How are you, bro? Tell me. America.
# VIJAYA: Good.
# Mohammed Khaled: Sorry. I couldn't reply to your email yesterday. I was in the office. Uh, but I got some emails.Okay.
# VIJAYA: Smoke detectors, uh, smoke alarm detectors.
# Mohammed Khaled: Okay. So, um, I I just want you to go ahead with this product.
# VIJAYA: Would does that unscrew replace
# Mohammed Khaled: The 300. Okay.
# VIJAYA: Okay. No. No worries. That's, uh,
# Mohammed Khaled: Uh, so it's gonna be, uh, shall I take it for the alarm to be just a short Sure. Thank you, Vijay.
# VIJAYA: Yeah. Thank you. Thank you.
# Mohammed Khaled: Thank you.Yes. Yes. That's correct. [/INST]
# </s>
# ****************************************************************
# row5 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Tracey: The Nalami Therapy Clinic. Anna speaking.
# Tamim: Hi. I was looking for Tracy.
# Tracey: Sorry. Yes. I've
# Tracey: done it on behalf of my mom. Yes.
# Tamim: Okay.
# Tracey: Tracy?
# Tamim: Hi, Tracy. This is Pameen from Cynergy.
# Tracey: Yes?
# Tamim: And I was following up on the inquiry which you made online for your hot water
# Tracey: Yep.
# Tamim: upgrade. How can I help you today?
# Tracey: Well, so I just wanted to know what
# Tracey: how much just what
# Tracey: sorry. Just wait. Um,
# Tracey: sorry. Just wait for me because I you muck it up, it'll break.
# Tamim: Take your time. No worries.
# Tracey: Okay.
# Tracey: What
# Tracey: how much does it cost for
# Tracey: new hot water?
# Tracey: Machine too.
# Tamim: Okay. Gracie Mhmm.
# Tracey: Yeah.
# Tracey: Yep.
# Tamim: I can give you an estimated price now. Before that,I will collect few informations. You got 5 minutes for me. Right?
# Tracey: Well, I'm not
# Tracey: I just don't know what the, um, so I
# Tracey: just need to go into the house to have a look at what the hot water service
# Tracey: is when I could be able to tell you what we've got.
# Tamim: Mhmm.Okay. Do you know, is it a gas or a electric hot blower?
# Tracey: I think it's guest.
# Tracey: Yes.
# Tamim: It's gas. Okay. And it's located outside of our house. Right?
# Tracey: Yes. Yep.
# Tamim: Got it. And, Tracy,how old is your hot water system?
# Tracey: Good 10 years plus.
# Tamim: Okay. It's probably more than a decade.Alright?
# Tracey: Yes.
# Tamim: Got it. And, Tracy, how many bedrooms are there in the houseAlso, how many people are using the hot water most of the time?
# Tracey: So there's, uh, there's 3 bedrooms?
# Tamim: Mhmm.
# Tracey: But there's only 1 person in the house.
# Tamim: Okay. Got it.Tracy, I strongly recommend installing a 300 liter capacity heat pump system for her home. To eliminate any future inconvenience,
# Tracey: Yep.
# Tamim: Do you have any other preference in mind?
# Tracey: No. No.
# Tamim: Okay. Tracy,your estimated price for the 300 liter capacity heat pump system replacement will be only $660, fully installed,
# Tracey: Okay.
# Tamim: after all the rebates provided and no additional work required.
# Tracey: Okay. Cool.
# Tracey: And
# Tracey: so that's all installation and everything done.
# Tamim: That's right.
# Tracey: That's right. Okay. And do you have are you able to email me
# Tracey: what the
# Tracey: 300 liter
# Tracey: heat pump that you would use.
# Tracey: Yep.
# Tamim: Of course. I will send you some key details of the
# Tracey: Yep.
# Tracey: Yep.
# Tamim: 300 liter capacity heat pump system, andalso, I will attach the brochure as well. So when you get this chance, have a look at it.
# Tracey: Yep.
# Tamim: And, Tracy, do you want me to prepare a formal quote for you?
# Tracey: No. That's totally fine. If you can just send me that through, and then I can
# Tracey: contact you.
# Tamim: Sure. No problem.
# Tracey: Want to have a bit of a look at it and
# Tamim: Sure.
# Tracey: Work it out.
# Tamim: Tracy
# Tracey: Beautiful. Um, the other do you deal with all the other
# Tracey: incentives or not?
# Tamim: Yes. Basically,
# Tracey: That are on or use that? Yep.
# Tamim: we will do all the paperwork from our side.
# Tracey: Yep.
# Tamim: And you just need toLet us know what's gonna be a suitable day for the installation.
# Tracey: Yep.
# Tamim: And we will go ahead and install it straight away. That's it. Very simple.
# Tracey: Yeah. Okay.
# Tamim: Hello?
# Tracey: So the other thing that I noticed on your website, there was about the
# Tamim: Yeah.
# Tracey: aircon
# Tracey: system. So she's got a, um, got a
# Tracey: gas
# Tracey: Peter.
# Tracey: Is she able to do an upgrade to
# Tracey: a split system?
# Tamim: Absolutely. So
# Tracey: As well? Oh, and what's the eligibility for that, or how does that work?
# Tamim: Mhmm. She's using a gas ducted heating system. Right?
# Tracey: Yes. Yep.
# Tamim: Got it. Okay. Tracy, let's get the hot water system sorted first.
# Tracey: Yes.
# Tracey: Yep.
# Tamim: That process is more easier. Let's go for the aircon later on. How does that sound?
# Tracey: Okay. So it doesn't matter if you've gone
# Tracey: if she's done the hot water, that doesn't make her be eligible non eligible for the
# Tracey: No.
# Tamim: No. So you are still going to be eligible for that
# Tracey: Yep.
# Tamim: solar panels, the air cons, fan seals. There's nothing to worry about there.
# Tracey: Yep. Okay. Beautiful. Thank you very much.
# Tamim: Mhmm. So, Tracy, I would like to have another chat with youwith a formal quotation in front of us to go over the details. So
# Tracey: Yep.
# Tamim: what do you reckon when can I, uh, when can I haveanother conversation with you?
# Tracey: Can you would Friday be okay?
# Tamim: Friday. This upcoming Friday. Right?
# Tracey: Yes. Yep.
# Tamim: Of course. No problem. Friday, what time is good?
# Tracey: What time do you start and finish?
# Tamim: 10 in the morning and 7 in the evening.
# Tracey: Go go with 10 o'clock in the morning. That'll be fine.
# Tamim: Sure. Sounds good. AndTracy, to ensure that the price I'm going to quote you is going to be the final price,
# Tracey: Yep.
# Tamim: and also to make sure there is no additional work
# Tracey: Yep.
# Tamim: required for the replacement, I need couple of pictures from you.
# Tracey: Yep.
# Tamim: I need a picture of the main electric switchboard of our house anda picture of our old gas hot water system. That's it.
# Tracey: Switchboard?
# Tamim: Mhmm.
# Tracey: And
# Tracey: hot water.
# Tamim: Yes.
# Tracey: And who do I send that photos to?
# Tamim: You you can send the pictures on thisnumber. You can text me, or you can reply to my email as well. Whatever is convenient for you.
# Tracey: Okay. Done.
# Tracey: And what was your name? Sorry.
# Tamim: My name is Tamim. It's tamim.
# Tracey: Beautiful.
# Tamim: Mhmm. And
# Tracey: Thank you very much for your help. Bye.
# Tracey: Yes.
# Tamim: No problem at all. And, Tracy, few more questions. It's a single story house. Right?
# Tracey: Yes.
# Tamim: Okay. And the main electric switchboard of the houseis it on the same side as of the hot water system, on the same wall, or some other side of the house?
# Tracey: I'll need to check that.
# Tamim: Mhmm. Okay. No problem.Uh, Tracy, when you get the chance to check it out, please get a rough approximate distance from the switchboard to the hot water system. Just a rough rough idea would be fine. And based on that, I will prepare the quotation for you. Okay? Alright.
# Tracey: Yep. Excellent. So
# Tracey: I can do I'll try to do that today and get that back to you.
# Tamim: Sounds great. And, Tracy, she's the owner and occupier ofthe property where the system is going to be installed. Right?
# Tracey: Yes. Yes.
# Tamim: Okay. And
# Tracey: Yes.
# Tamim: that property value is under $3,000,000. Right?
# Tracey: Yes.
# Tamim: Okay. And, Tracy,she's working or she's a customer?
# Tracey: Pension on now.
# Tamim: Okay. AddTracy, this property address has not previously received a hot water rebate or a solar battery rebate under the solar homes program. Right?
# Tracey: No.
# Tamim: Got it. Okay. Tracy, is there any questions that I can answerfor you at the moment?
# Tracey: Not at the moment. If I get those back to you, then we can go from there.
# Tamim: Saw
# Tracey: Yep.
# Tamim: good. I'll wait for the pictures for now. Once I receive it,I will prepare a formal quotation for you based on the pictures and the information you have provided. Add
# Tracey: Yep.
# Tamim: I'll get back to you Friday, 10 in the morning. Sounds good?
# Tracey: Wonderful. Thank you very much.
# Tamim: Thank you very much. Please feel free to give me a call if there's any questionsconcerns. Okay?
# Tracey: Excellent. Thank you.
# Tamim: Thanks very much. Have a great day.
# Tracey: You too. Bye.
# Tamim: Bye bye.[/INST]
# </s>
# ****************************************************************
# row6 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Davie: Fire Cold calling. How can I help?
# Michael: Hi. I had a question about your fire cold plunge.
# Davie: Yes. How can I help?
# Michael: It isdoes it need to be in the garage or under, like, a cover of shade? Or can it just be out in the backyard?
# Davie: Oh, it is the sound designed for outdoors use. However, um, as
# Davie: purpose that we need a cover for it is we want to keep it out of direct sunlight.
# Davie: The UV rays will
# Davie: over time affect the vinyl.
# Davie: Design of the or, I mean, the product.
# Michael: Got it. Okay.
# Davie: Oh, that's all?
# Michael: Okay. Thank you. How much is that? Oh, and how muchum, how much is the voltage when, like, you're plugging it into an outlet? Do you know the voltage on it?
# Davie: Yes. You can use a normal household
# Davie: plug, which is 120 volts.
# Michael: 20 volts.
# Davie: Hello?
# Michael: Hello?
# Davie: Yes.
# Davie: Sorry. That's 110 volts.
# Michael: 110 volts.
# Davie: Mhmm.
# Michael: Okay. And then just, uh,I had one more follow-up for the outside since um, we technically don't have any kinda shade for outside. I just wanna I'm not sure if it'll be durable outside because we kinda live in a little warmer climate to in the summer that gets to above 90 to a100. I just like, is it okay or will it fade over time, or do you guys have a cover for it? So I'm just kinda curious what I could do
# Davie: Yes. So we do have a, um, waterproof cover
# Davie: that
# Davie: that we sell as an accessory on online or on our website.
# Davie: Um, we do have a lot of customers in Arizona that
# Davie: purchase
# Davie: the product that
# Davie: um, works just fine. So we will not have any issues with the
# Davie: climate. We just want to
# Davie: make sure that it's out of, you know, direct sunlight. So
# Davie: we can preserve other
# Davie: the aesthetic of the product, which is the vinyl wrap.
# Michael: Okay.Gotcha. So the people in Arizona, they have to keep it out of direct sunlight because I'm a little confused on you know, if we're in a warmer climate, we we basically can't keep it out of direct sunlight. Our only option is to use the cover.
# Davie: Yes. And it's also designed
# Davie: in Texas. So, basically, it will
# Davie: survive that type of
# Davie: climate or temperature.
# Davie: Yeah.
# Michael: Okay. So you're saying it will survive, but you're sayingthat it will fade. So I'm just kinda just confused on, um, if it will be good or not. Before I purchase this kind of 3,000 $4,000 cold plunge. You know?
# Davie: Yeah. The only main concern
# Davie: of it being outside is
# Davie: just the vaneal because, uh, of course, we don't want your product over
# Davie: 2
# Davie: Um, Luz is, you know, aesthetic.
# Davie: Won't be pleasing in the eyes if the vein around
# Davie: Well,
# Davie: over time, um,
# Michael: Okay.
# Davie: looks like it's worn out.
# Davie: Things like that. So that's the only concern of it being outside. But when it comes to
# Davie: performance and usage or durability,
# Davie: Yes. It is designed for outdoor use.
# Davie: And it can survive temperatures in Arizona and, um,
# Michael: Okay.
# Davie: Texas. So there shouldn't be any problems with it.
# Davie: Also, um, all our products comes with a 1 year warranty, which
# Davie: means all minor and major issues
# Davie: will be, um, assisted, and we'll help you with it a 100
# Michael: Okay.I'm just curious. I know, uh, the founder, Nick. Um, by any chance, he ever available to talk to him if I have, like, if I have any questions? Because um, I don't know. I just feel like I would love for him to talk to me 1 on 1 about this product.
# Davie: You can. We can schedule
# Davie: a call
# Davie: with Nick
# Davie: Um, I can send you a link where you can schedule a call with him.
# Davie: Or I can also ask for your phone number and, um, give that to him.
# Michael: Yeah.Because I keep I called him and left him a message, and I've heard he's available. To talk at some point, but, yeah, I'd just love to have a conversation with him before I purchase it.
# Davie: Sure. So, um, yeah. What's your phone number?
# Michael: That'd be 714813 8724.
# Davie: And your name, sir?
# Michael: Mike Smith.
# Davie: Thank you, Mike. Um, is there any specific
# Davie: question that you want to ask him?
# Michael: No. I justkinda wanted to hear firsthand from him about why I should buy it and if there are any issues that it could possibly face with the climate I'm in. Um, just before I decide to fully go all in and purchase it.
# Davie: Okay. I'll let him know. Um, hopefully, he's still available
# Davie: during this hour because we just we're we're just normally up until 5
# Davie: PM. Just
# Michael: Right.
# Davie: you know, just so you know. But I'll let him know now.
# Michael: Yeah. I'vetomorrow works as well.
# Davie: Hi.
# Davie: Tomorrow morning?
# Michael: Okay.Yeah.
# Davie: Okay. We'll let him know then.
# Michael: Okay. Sounds good.
# Davie: Alright. Thank you for your time.
# Michael: Thank you.
# Davie: Have a great day. Goodbye.[/INST]
# </s>
# ****************************************************************
# row7 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Vincent John: Yes. Hello. Uh, good afternoon. This is Vincentfrom Rev Moto painted auto body parts. I'm calling back from Miss Call. How are you doing today?
# Tyler: Hi. Yeah.
# Tyler: I'm good. How are you?
# Vincent John: Awesome. Yeah. Doing great myself.I believe you were looking for the side view mirrors, correct, for the Chevrolet
# Tyler: I'm yeah.
# Vincent John: Mhmm.
# Tyler: I'm looking for mirrors for a 25100.
# Vincent John: 2,000
# Tyler: 2018, and I'm needing
# Tyler: 18, and I'm needing the color match.
# Tyler: But I I don't need the whole mirror. Like,
# Tyler: I can mine are chrome now. I really just need, like, the
# Tyler: plate or the housing or however. I don't wanna buy all brand new mirrors.
# Vincent John: So you're justneeding the cover. Is that it? It's the hover. Mhmm.
# Tyler: Yeah. Yeah. I just need
# Tyler: Yeah. The top and the bottom.
# Vincent John: Top and the bottom cover.
# Tyler: Do you want this pint code?
# Vincent John: Let's see. Let me check first ifI have this one available.
# Tyler: Okay.
# Tyler: Do do you only sell color match?
# Tyler: Or do you sell them ready to paint?
# Vincent John: Alrighty. Actually, weare the ones painting them.
# Tyler: Okay.
# Vincent John: So we source the part, and then we paint it, uh, depending on the paint code.
# Tyler: Okay.
# Tyler: Okay.
# Vincent John: We only have the the whole mirrors, uh, listed here.
# Tyler: Yeah.
# Vincent John: Do you happen to have your VIN? Uh, we can have our team check
# Tyler: Yeah.
# Vincent John: However, uh, the results, that will be tomorrow.
# Tyler: Yeah. Hold on one second. Do you want
# Tyler: the whole VIN or the last 8 of the VIN?
# Vincent John: Uh, the whole one.
# Tyler: Okay. Uh, let me know when you're ready.
# Vincent John: Let me bear my notes.Go ahead.
# Tyler: 1
# Tyler: v
# Tyler: as in goat, c as in cat,
# Tyler: 1, k as in cat,
# Tyler: x as in x-ray,
# Tyler: e as in elephant,
# Tyler: y as in
# Tyler: u,
# Tyler: 5
# Tyler: j as in John, f as in Frank,
# Tyler: 24
# Tyler: 50
# Tyler: 11.
# Vincent John: Uh, you do need both sides. Right?Nothing right?
# Tyler: Yeah. I want both sides
# Tyler: I want both sides of them.
# Tyler: What if what if I took my mirrors apart
# Tyler: and sent them to you? Well, you can't you can't paint over chrome, can you?
# Vincent John: Unfortunately, we can't. So with the
# Tyler: That's what I thought.
# Vincent John: Chrome, we can. However, it will take over time, so we don'treally recommend paying them over them.
# Tyler: That's what I thought.
# Vincent John: Let's just say, like, a a month or 2.
# Tyler: Is there no is there no way to sand it down?
# Tyler: Right.
# Vincent John: We really can't recommend. Uh, there are also customers who, you know,uh, really wanted their Chrome painted. Unfortunately, they will really flake off. No matter what.
# Tyler: Okay. That's what I've been told.
# Tyler: That's what I've been told. It is, like, away after a while.
# Vincent John: We can do that, but, uh, unfortunately,yeah,
# Tyler: It's okay.
# Tyler: Yeah.
# Vincent John: There's no way for us to, you know, ensure oh,
# Tyler: I I understand.
# Vincent John: Uh, what's your email address? Uh, I'll send the quote once it's available.
# Tyler: Okay. The paint code?
# Vincent John: Uh, the email address.
# Tyler: Oh, the email. It's g
# Tyler: eise
# Tyler: 2707@hotmail.
# Vincent John: And don't worry about the PIN code. We can, uh, alsoconfirm it with your VIN.
# Tyler: Okay.
# Vincent John: So we got you covered.And, also, as
# Tyler: Yeah. It's some kinda red. I don't know what it's called. Cajun red or something.
# Vincent John: No worries. We can confirm that one. I missed your name. Um, may I have your name again?
# Tyler: Tyler, t y l e r.
# Vincent John: My childWhat state are you in, Tyler?
# Tyler: Tennessee.
# Vincent John: I see. Right.So I'll be checking both sides, uh, upper and also lower mirror cover. And then once I have them, uh, the once I have the prices, I'll send it over to you. By email by tomorrow.
# Tyler: Alright, man. Pre appreciate it, man.
# Tyler: Thanks.
# Vincent John: You're welcome. And you can always, uh,send us a message if you have any questions. K?
# Tyler: Okay. Thank you.
# Vincent John: You're welcome. Have a good day. Bye bye.[/INST]
# </s>
# ****************************************************************
# row8 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# chandrashekar: Hello?
# Matt: Hi, I think we got disconnected there.
# chandrashekar: Hey. Sorry. I think, uh, yeah. I think that's for me as well. Uh, for me, are you there?
# chandrashekar: Yes. I'm here. Yeah. Uh, thank you, Matthew, for accepting our call. Thank you.
# Matt: Of course. Yeah. Andwhat is your wife's name again?
# chandrashekar: Uh, Somya.
# chandrashekar: Somya here.
# Matt: Sony oh, Sonya. Hi. We we met before. Right?
# chandrashekar: Yeah. Yeah. Yeah. I think we've spoken before.
# Matt: Yeah. Yeah.Well, thanks. Thank you so much for getting me, um, or arranging this phone call. I figured that it would be best for us just to talk
# chandrashekar: Yeah.
# Matt: since you had a bunch of questions. In that way, I can get your, uh, responses. Soso
# chandrashekar: Yeah. Do you have WhatsApp handy?
# Matt: yeah.
# chandrashekar: I sent out via email. Do you have those questions with you?
# Matt: I do have it in front of me.
# chandrashekar: Okay. Cool.
# Matt: Yeah. Yeah. So the first question was sinceshe has a broad topic of interest, will you help her narrow it down to a topic which will yield a publication? And the answer is yes. That is the reason for the, um, okay. So we're not doing Launchpad. That is the reason for the core program is what we'll do in the first couple sessions of the core program is narrow down the topic. Um, it will be the topic will be related to premed biology genetics cancer. And, uh, probably most likely around the area of cancer cell biology. For example, the impact of hypoxia inducible factors on tumor angiogenesis and metastasis in glioblastoma or something related to that.
# chandrashekar: Okay.
# Matt: So originally,
# chandrashekar: When is Aditi around?
# Matt: What's that?
# chandrashekar: Uh,
# chandrashekar: Uh, no. No. Somebody was asking me, actually, but it is around so that he can also join this
# chandrashekar: call.
# chandrashekar: Um, let me check.
# chandrashekar: Sorry for that, Matthew. Give me a second.
# Matt: No. We're good. We're good.
# chandrashekar: Yeah. Just checking with her.
# chandrashekar: The thing is we are told that even there are broad topics,
# chandrashekar: uh, it's difficult to find a paper. You know, you can write a journal, but
# chandrashekar: it will never get published if it is a broad topic. And cancer is a seemingly very
# Matt: Yep.
# chandrashekar: big topic. Right? Cancer is within so many researches have already happened.
# chandrashekar: So she's open to actually switching top topics
# chandrashekar: of her interest. I mean, uh, there are other topics in overall interest
# Matt: Mhmm.
# chandrashekar: in medicine. Cancer was just one of the major topics,
# chandrashekar: uh, but not limited to that.
# chandrashekar: So that way, he's open to switch over topics as well, but
# chandrashekar: uh, yeah, we wanna see what what it will
# chandrashekar: end of the
# Matt: Yeah. And that's totally fine. So there's 2 routes that she can do.She can do the core program, and at the beginning of in her first two sessions, she can figure out an original research idea based on her interests. Or she can sign up for the Launchpad program, which allows her to meet with 3 mentors prior to starting the core program. Where she can workshop bunch of different, uh, original research ideas. So she has 2 options there.
# chandrashekar: Okay. And what is the difference with that too? Is it the is
# chandrashekar: it the same package which we are taking or is it something else?
# Matt: So we originally did not go with the LaunchPad.We talked about how she can workshop ideas in her first couple sessions, um, in the core program. But we would connect her with someone in her area general area of interest dress, which would be cell biology cancer biology, premed, genetics, someone an expertise in that. And then in the first couple sessions of the core program, she can figure out her original research topic. The other example would be that I just mentioned is she could do LaunchPad. And that would allow her to meet with 3 mentors for 3 1 hour sessions. And the whole purpose of that whole program is to figure out an original research idea.
# chandrashekar: Mhmm. Okay.
# chandrashekar: So
# chandrashekar: Then then I think we had our second question.
# chandrashekar: Second question was, will she allowed to talk to professors till she figures out who is the right
# chandrashekar: professor for her?
# ...
# Sanjivan: Yep. No problem at all. Thank you so much.
# Sanjivan: Okay.
# Sidratul Sadia: Alrighty. Do you have anything else for me?
# Sanjivan: I think I'm good because I don't think the wiring is
# Sidratul Sadia: Mhmm.
# Sanjivan: going to be anything more than 6 to 8 meters. There's a new
# Sanjivan: new power board in there in the garage, so they can take it through there.
# Sanjivan: Uh, and, uh, I just need to pull the car out so that they have access
# Sanjivan: to the backyard.
# Sidratul Sadia: Yeah. That'd be great.
# Sanjivan: Yep.
# Sanjivan: Okay.
# Sidratul Sadia: Yeah. Okay. Thank you.Yes.
# Sanjivan: Okay. And, uh, you accept American Express?
# Sanjivan: Okay.
# Sidratul Sadia: Yeah. We do.Yeah.
# Sanjivan: Alright. Fine. I'll pay by American Express. Okay.
# Sanjivan: Thank you.
# Sidratul Sadia: Alright. Thank you. Bye.
# Sanjivan: Bye.[/INST]
# </s>
# ****************************************************************
# row10 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Mary: Good afternoon. Harris and Barra Group. How can I help you?
# Tom: How you going,Tom from Bellina. I've got a job in Wollongong, Turoji. Do you guys have labors down this way?
# Mary: Yes. We do.
# Tom: Yeah. Am I able to get, uh, 2 laborsfor tomorrow, please?
# Mary: Yeah. No problem. Let me just quickly transfer your call
# Tom: Yeah.
# Mary: one of the consultants, and they will give you all the details of
# Mary: how do we manage, yeah, everything.
# Tom: Yeah. I've normally speak with WillUh, it's we got an account with him and everything. I've already I've done it before. Yeah.
# Mary: Yeah. But Will is snowing today.
# Mary: I will put you through Shane, and he will be able to help you. Okay?
# Tom: Thank you.
# Mary: No worries. Thank you.
# Tom: Alright. Bye.
# Mary: Sorry. What is your name again?
# Mary: And the company name?
# Tom: Tom from Planet Project.Blaine Project.
# Mary: Okay. So Tom from Salem Projects. No worries. Give me 2 seconds.
# Tom: The lane of theYeah. Berl0n a.
# Mary: Okay. No worries.
# Mary: Hello. This is Shane speaking.
# Tom: Hey, mate. Tom from Blaine. How are you going? This one here. I'll leave it here.
# Mary: Good, Tom. How are you going?
# Tom: Yeah. Good. Good. I just need, uh, 2 laborersdown at a job at tomorrow, please.
# Mary: Okay. No worries. Um, Thomas, what is the company that you're from? Sorry.
# Tom: The lane of projects?
# Mary: Billing, how do you spell that, please?
# Tom: J a r
# Mary: Mhmm.
# Tom: l I n a.Yeah.
# Mary: Mhmm. For this? Okay.
# Mary: No. And what's the site address, please, Tom?
# Tom: 82 Teroggi Road.
# Mary: Yes. I've called. And so it's Roger, please?
# Tom: Toradgi.
# Mary: Right. Okay. Alright. So it won't go
# Mary: Yep.
# Tom: Yep.
# Mary: Okay. 7 AM side is it?
# Tom: Yeah. It is, mate. Yep.
# Mary: 7 AMS. And, Tom, are you the site, um, contact there?
# Mary: Yep.
# Tom: Yeah. I am. Oh, yeah. Yeah. Yeah. Just send me.Yeah.
# Mary: Yeah. Alright. And and what are they doing? What's the, um, discuss the west
# Tom: Uh, just a general library. Just hardening up.Moving materials around. Long as they can speak English, mate, they're happy to work all day. Problems.
# Mary: Yep. No worries.
# Tom: Yeah.
# Mary: I had some guys down there doing a job with Apex Civil.
# Mary: Um, we just finished up on Friday, so I'll give those guys a call first.
# Mary: Um, because they're reliable. They went every day.
# Mary: Come let me
# Tom: Yeah. Sorry. This is for tomorrow. Yeah?
# Mary: Correct. Yeah. Yeah. They'll finish up on Friday because their job's finished.
# Tom: Yep.
# Mary: Um, but I'll I'll give them a call to see if they're free tomorrow to go to your site.
# Tom: Yep.
# Mary: Can I please get your phone number to someone as well so I can give you a callback and confirm everything for
# Tom: Yeah. 0418.
# Mary: Yep?
# Tom: 27
# Mary: Mhmm.
# Tom: 614
# Mary: Alright. 76
# Mary: Okay. No. It's my name is Shane.
# Tom: Yep.Alright.
# Mary: You a callback very shortly, okay, once I confirmed everything. K? So that's 0418
# Mary: 287-614.
# Tom: Yeah. Thank you.
# Mary: Cool. I'll come back as soon. Take it, Tom.
# Tom: Alright. Please. Bye.
# Mary: Bye.[/INST]
# </s>
# ****************************************************************
# row11 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Priscilla: Travel Wellington CBD. Faye speaking.
# Zane: Hey, Faye. It's Zane here from Designer Journeys. How are you going?
# Priscilla: Good. How are you?
# Zane: Good. Last time we spoke withBecca, uh, before Easter weekend, and you're off to Hawaii. Did you have a nice trip?
# Priscilla: Yeah. I did. Thank you. Yeah. It was good. Long time ago.
# Zane: I know. I've just come back off my leave now. So we both had a bit ofin between, and, uh, yeah, I thought I'd just touch base and see if we could like, pop in that time for, uh, the onboarding on the virtual onboarding. I didn't get a response back last time, but, uh, it was probably just timing and all. And yeah, I was hoping maybe the latter part of the year might be better suited.
# Priscilla: Yeah. Probably.
# Priscilla: Um, so we've got 1, 2,
# Priscilla: 3 going on holiday in the next week. Um, so the next
# Zane: Alright.
# Priscilla: Yeah. August has got, um, because we've we've
# Zane: Oh, nice.
# Priscilla: more staff now, so we're up to 9 of us. Um, but they still hasn't
# Priscilla: Yeah. We're just go. Um, but we definitely had a couple come in with
# Priscilla: with existing leads, and then we already had some booked with Dave. So the next
# Priscilla: probably, I'm gonna say, all of August is gonna be quite tight in terms
# Priscilla: time framing, so I would take that out of the diary. But, um,
# Priscilla: and then our boss goes away with them.
# Priscilla: But potentially, like, late September or something like that, in October would
# Zane: Yeah. I got a stowed.
# Priscilla: would be better in the diary if you wanna flick through a couple of options, and then I can
# Priscilla: um, pass them through to our own operator and see what
# Priscilla: what she wants to to
# Zane: Yep. Easy breezy. If say if I select your email, um, say nowand then, um, pop through, would you better reply back with the um, agents that are on on the grounds? And I'll I'll create logins for everyone, make sure that it's
# Priscilla: Yeah.
# Zane: pull up today. And then, yeah, to September, I'll check for a couple of options and
# Priscilla: Yep.
# Zane: look, not everyone has to turn up, but if at least if we get 3 or 4 a yearalong, then the the snowball, we can, um, the rest the risk can learn off each other.
# Priscilla: Perfect.
# Zane: Easy.
# Priscilla: Yeah. Perfect. Yeah. No. That sounds like a plan. Yep. Um, so yep.
# Priscilla: Pop that through, and I'll, uh, I'll come back to you as I can.
# Zane: Thanks. Sorry I left it so long in between.
# Priscilla: Uh, don't worry.
# Zane: Also been hectic carrying too and trying to establish, um, which rolesgonna come into, and, yeah, time goes nowhere. Hey.
# Priscilla: Oh, gosh. No worries.
# Priscilla: Okay.
# Zane: Alright. Well, I appreciate you, Faye. And, um, yeah, I'll I'll flick your email right away.Thank you.
# Priscilla: Perfect. Alright. Speak soon. Bye.
# Zane: Bye.[/INST]
# </s>
# ****************************************************************
# row12 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Kate: Hi.
# New Justcall: There you go, Kate. Um, I'll ring that number for the one at Western4 times now and answer.
# Kate: Okay. He's not answering. Alright.
# Kate: Give me 2 seconds.
# Kate: Where else are we?
# Kate: Alright. Give me
# Kate: 2 seconds. I'll see what's going on. I do say it should be fine, but I'll just double check for you, Nick. Give me
# Kate: 2 seconds.
# New Justcall: Okay.It's gone up? Take care. Okay.
# Kate: Sorry, Nick.
# New Justcall: Hi, Jasmine.
# Kate: Oh, you're still there? Okay. Yeah. That's fine. Head out there for me.
# Kate: He's a regular. So if he's not there, just let me know and send me through the VIN number, and we can fix
# Kate: it up on our end if need be.
# New Justcall: Okay. No worries. I'll see what I can do.
# Kate: Yep. When you get there, give him another give him another call and see if you can get a hold of him when you're there
# Kate: again and just let him know. But, yeah, he it should be all good.
# New Justcall: No worries. Thank you.
# Kate: Alright. Awesome. Thank you.
# New Justcall: Yeah. Thank you. Bye. Thanks.
# Kate: Alright. Bye.[/INST]
# </s>
# ****************************************************************
# row13 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Sonia: Hello? Vanessa speaking.
# William: How are you today?
# Sonia: Good. How are you?
# William: Very well. Thank you.It's been quite a while since we've reached out.
# Sonia: Sorry. Where are you calling from? I I
# Sonia: reception's not very good. You were cutting off.
# William: Uh, calling from OnDeck.
# Sonia: Well, is it
# William: Yes. That's right.Yeah.
# Sonia: Hello? Yes. That's right.
# Sonia: Yeah. Long time no see.
# William: Yeah. Yeah. Quite a while. I was just I just wanted to give you a quick call, check-in, see howthis was going?
# Sonia: Yes.
# William: Yep.
# Sonia: Uh, I'm actually just driving at the moment.
# Sonia: But, yeah, it's going it's okay.
# William: Yeah.
# Sonia: Well, we we just don't have a whole lot of, um, cash flow loan.
# William: Yeah.
# Sonia: Like, clients. So yeah.
# William: That's okay. What have you been busy with? Have you been doing any type of
# Sonia: Not something, you know, we do.
# William: commercial or mainly resi?
# Sonia: Uh, yeah. Sorry. A bit of, um, mainly red meat, but a bit
# Sonia: commercial as well. We do, um, mainly, um,
# Sonia: Well,
# Sonia: Um, some development loans
# Sonia: mainly, um, development
# Sonia: yeah, related
# William: Yeah. So both
# Sonia: for our commercial and, um, office
# Sonia: Yeah.
# William: Right. So you're mainly in that development space forand resi as well? Or
# Sonia: Yeah.
# Sonia: And resi as well. Yes. Mainly resi resi is
# Sonia: bread and butter.
# William: Yeah. Oh, no. That's okay.We always assume around 25% of a resi broker's book is self employed. Do you think that would be similar for you? More or less.
# Sonia: Yeah. I'm I'm
# Sonia: self employed.
# Sonia: Have a barcodeer team of, um,
# Sonia: 8 brokers that work with me.
# William: Oh, really?
# Sonia: Yeah.
# William: That's a big team.
# Sonia: It's okay.
# William: No. That's totally fine. Do you have do they do the wholedeal themselves, or do you have any loan writers or admin staff?
# Sonia: Uh, we have a couple of admin stuff, but, um, mainly, we have
# Sonia: BDM team, that broker team, and, yeah, and assist team.
# William: Oh, excellent. Um, do you think, uh, what I can do is send youthrough some information about us and just our lending criteria
# Sonia: Yeah.
# William: Do you think it'd be worth, uh, passing that around the team just so they're aware of it?
# Sonia: Yeah. Kendzer.
# Sonia: Canter.
# William: Yeah. Excellent.Um, and if, uh, yeah, otherwise, if they have any questions, they can always reach out to me.
# Sonia: Yep.
# William: Um, we can even organize a Zoom if if that's something they seem interested in or
# Sonia: Interesting. Yeah.
# William: or would be worthworth having a Zoom session?
# Sonia: Yeah.
# Sonia: Sounds good. And, um, so, um,
# Sonia: what's
# Sonia: what's the
# Sonia: fees for the, um,
# Sonia: or the interest rate for cash flow as
# Sonia: Yeah.
# William: Yes. So it's all dependent on the strength of the applicant. Of
# Sonia: Yeah.
# Sonia: Yep.
# William: course, but that's probably fall between 20 to 26% simple interest
# Sonia: Yeah.
# Sonia: Okay. 20 to 26%. Okay. And that's
# Sonia: um, just on the, um, so no security and just on
# Sonia: The
# Sonia: the books
# Sonia: Right.
# Sonia: Yep.
# Sonia: Yeah.
# William: Yeah. Correct. There's no security attached to it at all.
# Sonia: Yeah.
# William: We just take a director's guarantee, and that's it.Client doesn't need to be asked back to anything.
# Sonia: Oh, okay. So they don't need
# Sonia: to be, um, you know, have, um,
# Sonia: sufficient assets or receivables in their
# Sonia: Account.
# William: No. So we we go purely off the bank statements and what their turnover is.
# Sonia: Okay. So the bank statements and turn it over. Okay. Cool.
# Sonia: Alright. Thank you. Thanks for letting me know.
# William: No worries at all.
# Sonia: And, um, if you send some
# Sonia: stuff through, then I'll let the brokers know too.
# Sonia: Thanks.
# William: Yeah. Absolutely. I'll do that right now.
# Sonia: Okay. Thank you. Bye bye.
# William: Thanks, Sonya. Have a great day.
# Sonia: Have a good day.
# Sonia: Features
# William: You too. Bye bye.[/INST]
# </s>
# ****************************************************************
# row14 and the row is:<s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# Nyah: You for calling Events and Adventures. This is Naya. How may I help you?
# Kshipra: Hi, Nada. This is BrookeI have a meeting with Annabel, uh, today at 4:30, and I was, uh, running late, but I cannot find any uh, Zoom ID in the email.
# Nyah: Okay.
# Nyah: Um, let me go ahead and double check our, um, system for you here. Give me
# Nyah: One moment.
# Kshipra: Thank you.
# Nyah: Let me go ahead and search our
# Nyah: for your phone number first.
# Kshipra: But, uh, no one is responding on the text. It they were just responding, like, 1 minuteago.
# Nyah: Let's see. Uh, I do see some text from 6:27 PM CST.
# Nyah: Standard Time. Okay. Um, no problem.
# Nyah: Let me see here. I do see that the, uh,
# Nyah: appointment is scheduled on here.
# Kshipra: Mhmm.
# Nyah: Let me see.
# Nyah: Alright.
# Nyah: Um,
# Nyah: I will just go ahead and see. Uh, let me see if there's anybody on standby
# Nyah: Um, worst case scenario, we would just go ahead and reschedule for you, uh, to
# Nyah: a time where we will be able to hold it for you. Um, so let me double check and
# Nyah: see who is on standby, if any, for you. Okay? Give me one moment.
# Nyah: Okay. Thank you so much
# Nyah: for holding. Um, we don't have anybody on standby. We are very booked at this
# Nyah: moment. Um, would you have a time tomorrow for, um,
# Nyah: 6:30 the same time?
# Nyah: It's
# Kshipra: No. Tomorrowtill Thursday, I don't have any, uh, free time.
# Nyah: Okay. Do you, um, have
# Nyah: Saturday's free?
# Kshipra: Any any day in the weekday is fine for me, but, like, weekdays are workswork for me, but weekends won't work for me. I have pretty booked weekends. Yeah.
# Nyah: Oh, okay. Um, well,
# Nyah: when is the next time that you would have, uh, available?
# Kshipra: Maybe Friday.
# Nyah: Okay. That'll work.
# Nyah: Um, would it be, um, uh, what what time will work for you Friday? The same time?
# Kshipra: Let me check. One second.Friday. Do you have something for here, maybe on Friday, maybe 2 PM or something?
# Nyah: Yes. We could definitely do that. No problem.
# Kshipra: Okay. Then 2 PM on Friday.
# Nyah: Okay. I can definitely reschedule that for 2 PM off
# Nyah: Friday. Um, we don't need anything else from you, so you're all set. I got you down for that time.
# Kshipra: Okay. But can you send me this, uh, invite right now? Because I don't want to dothe same thing again and have you know, no one available at that time again.
# Nyah: Um, yes. We'll go ahead and send that to you, um, here in a second. Okay?
# Kshipra: Yeah. Like,that that's what I think last time also happened, but there was no there is no meeting invite in the email.
# Nyah: Yes. You you get the email you get the link invite, um,
# Nyah: 15 minutes before your meeting time, um, just to make
# Nyah: sure that you're here and everybody's here. Um, we we create that one at a
# Nyah: a time. We for everybody. All all the links are made for each person.
# Nyah: So it would come at the time of your meeting.
# Kshipra: Okay.
# Nyah: Alright. Okay. So I got you down
# Nyah: for, um, um, let's see here. You said 2 PM, uh, on Friday. Okay?
# Kshipra: Okay. Thank you.
# Nyah: Thank you. Have a great day.[/INST]
# </s>
# ****************************************************************

# %%
# def summarize(tokenizer, model, dialogue):
#     inputs = tokenizer(dialogue, return_tensors="pt").to(DEVICE)
#     inputs_length = len(inputs["input_ids"][0])
#     with torch.inference_mode():
#         outputs = model.generate(**inputs, max_new_tokens=256, do_sample=True, temperature=0.0001)
#     # Manually remove tensors from GPU to clear memory
#     del inputs
#     torch.cuda.empty_cache()  # Clear after each iteration
#     return tokenizer.decode(outputs[0][inputs_length:], skip_special_tokens=True)

# import os
# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# finetuned_generated_summaries = []
# for idx, row in enumerate(data_preprocessed["dialogue"]):
#     finetuned_generated_summary = summarize(tokenizer, model.to(DEVICE), row).strip() ##use of GPU (max 34.7GB )
#     finetuned_generated_summaries.append(finetuned_generated_summary)
#     torch.cuda.empty_cache()  # Ensure the GPU cache is cleared after each iteration

# %%
# For loop here clears memory after each iteration and does not cause out of memory error - map does
# import os
# import torch

# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# batch_size = 10  # Adjust based on your memory constraints
# finetuned_generated_summaries = []
# for idx, row in enumerate(data_preprocessed["dialogue"]):
#   finetuned_generated_summary = summarize(tokenizer, model.to(DEVICE), row).strip() ##use of GPU (max 34.7GB )
#   finetuned_generated_summaries.append(finetuned_generated_summary)
#   # Clear GPU cache
#   torch.cuda.empty_cache()

#   # Optionally delete variables to free up memory
#   del finetuned_generated_summary

# %%
data_preprocessed = data_preprocessed.add_column("finetuned_generated_summary", finetuned_generated_summaries)

# %%
# For loop here clears memory after each iteration and does not cause out of memory error - map does

# import os
# import torch

# os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
# batch_size = 50  # Adjust based on your memory constraints
# raw_generated_summaries = []

# for i in range(0, len(data_preprocessed["dialogue"]), batch_size):
#     batch = data_preprocessed["dialogue"][i:i+batch_size]

#     for row in batch:
#         raw_generated_summary = summarize(raw_tokenizer, raw_model.to(DEVICE), row).strip()
#         raw_generated_summaries.append(raw_generated_summary)

#     torch.cuda.empty_cache()

import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"
raw_generated_summaries = []
for idx, row in enumerate(data_preprocessed["dialogue"]):
  raw_generated_summary = summarize(raw_tokenizer, raw_model.to(DEVICE), row).strip() ##use of GPU (max 34.7GB )
  raw_generated_summaries.append(raw_generated_summary)

# %%
data_preprocessed = data_preprocessed.add_column("raw_generated_summary", raw_generated_summaries)

# %%
print(data_preprocessed[4]["dialogue"])
# Out:
# <s>[INST] You are a helpful assistant. Your task is to generate following dialogue summarization:
#
# VIJAYA: Hello?
# Mohammed Khaled: Hello? Uh, hi. Uh, good morning. Jay, Mohammed here. Mohammed,is signing. Eric does. It's a month for signing that you probably use.
# VIJAYA: Hello. Hello. Moment by. Hello?
# Mohammed Khaled: Alright. Hi. I am so sorry if I missed.Meet a basically hard connection, so I was going to reconsider the stuff. So I was working Yeah. I just I just I just I
# VIJAYA: Yeah. Yeah.
# Mohammed Khaled: yes. It it is. It is a beautiful How are you, bro? Tell me. America.
# VIJAYA: Good.
# Mohammed Khaled: Sorry. I couldn't reply to your email yesterday. I was in the office. Uh, but I got some emails.Okay.
# VIJAYA: Smoke detectors, uh, smoke alarm detectors.
# Mohammed Khaled: Okay. So, um, I I just want you to go ahead with this product.
# VIJAYA: Would does that unscrew replace
# Mohammed Khaled: The 300. Okay.
# VIJAYA: Okay. No. No worries. That's, uh,
# Mohammed Khaled: Uh, so it's gonna be, uh, shall I take it for the alarm to be just a short Sure. Thank you, Vijay.
# VIJAYA: Yeah. Thank you. Thank you.
# Mohammed Khaled: Thank you.Yes. Yes. That's correct. [/INST]
# </s>

# %%
#ground truth
print(data_preprocessed[4]["summary"])
# Out:
# Call Summary:
# 1. Mohammed apologizes for missing Vijaya's email and explains that he was in the office.
# 2. Vijaya mentions smoke detectors as a product of interest.
# 3. Mohammed suggests going ahead with the smoke detectors.
# 4. Vijaya asks about the process of unscrewing and replacing the detectors.
# 5. Mohammed confirms the price of the detectors as $300.
# 6. The call ends with both parties expressing gratitude.

# %%
print(data_preprocessed[4]["finetuned_generated_summary"])
# Out:
# INSTINST:
# 1. Mohammed apologizes for missing a hard connection and mentions working on something.
# 2. Mohammed mentions receiving emails and apologizes for not replying to Vijay's email.
# 3. Mohammed suggests going ahead with a product related to smoke detectors or alarms.
# 4. Mohammed confirms the replacement of the alarm to be short.

# %%
print(data_preprocessed[3]["raw_generated_summary"])
# Out:
# mma: Hi Carrie, it's Emma from 4 Paws. I'm checking in before your photo session tomorrow. Everything okay for an early morning appointment?
#
# Carrie: Yes, that's fine. And you?
#
# Emma: Good, thanks. I wanted to confirm some details. Your dogs are Bolen, a partner, Pepper, and Cheddar, correct?
#
# Carrie: Yes, that's right.
#
# Emma: Great. You're all excited for the session, I assume?
#
# Carrie: Yes, we are. We hope it won't rain.
#
# Emma: Don't worry, we're excellent at working around rain, and it's actually the best weather for photos. For Pepper and Cheddar, please bring them on a collar and lead instead of a harness for better photo opportunities.
#
# Carrie: Understood.
#
# Emma: You have a Corgi and a German Shepherd, correct?
#
# Carrie: Yes.
#
# Emma: That's an interesting pair! You mentioned wanting some beautiful natural shots in a bushland setting. Still interested in that?

# %%
import pandas as pd
# from time import strftime, localtime

# # Convert the dataset to a pandas DataFrame
# t = int(time.time()) ##in epoch
# a = strftime('%Y-%m-%d %H:%M:%S', localtime(t)) #in datetime format
path = "/content/drive/MyDrive/finetune_sum/comparison"
df = pd.DataFrame({
    'dialogue': data_preprocessed['dialogue'],
    'groundtruth_summary': data_preprocessed['summary'],
    # 'raw_generated_summary': data_preprocessed['raw_generated_summary'],
    'finetuned_generated_summary': data_preprocessed['finetuned_generated_summary']
    # 'raw_v0.2_generated_summary': data_preprocessed['raw_generated_summary']
})

# Save the DataFrame to a CSV file
# df.to_csv(f'{path}/baseModel _summaries_comaprison_output_train2.csv', index=False)
df.to_csv(f'{path}/finetune_comp_with_groundTruth.csv', index=True)

# %% [markdown]
# ##ROUGE metric evaluation
#
#
# *   ROUGE-L: Use it when you want to evaluate the quality of single-sentence summaries or when you care about the sequence of words in individual sentences.
# *   ROUGE-LSum: Use it when you are dealing with multi-sentence summaries and want to evaluate the overall coherence and structure of the entire summary.
# * Low Scores (0.1 - 0.2): Indicate poor performance, with minimal overlap and relevance.
# Moderate Scores (0.3 - 0.4): Common for well-performing models on challenging tasks.
# High Scores (0.5 - 0.6 and above): Indicate strong performance, though achieving such scores depends on the dataset and task complexity.
#
#
# *In our case focus on ROUGE-LSum*

# %%
"""
0.0: No overlap between the generated summary and the reference summary.
 This indicates that the generated summary is completely dissimilar to the reference.

1.0: Perfect overlap between the generated summary and the reference summary. This would mean the generated summary is identical to the reference.


"""
rouge = evaluate.load('rouge')
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %%
# Fine-tuned model ROUGE
model_rouge = rouge.compute(
    predictions=data_preprocessed["finetuned_generated_summary"],
    references=data_preprocessed["summary"][0:len(data_preprocessed["finetuned_generated_summary"])],
    use_aggregator=True,
    use_stemmer=True,
)
model_rouge
# Out:
# {'rouge1': 0.6904313178719867,
#  'rouge2': 0.5203692657790906,
#  'rougeL': 0.5980214859662567,
#  'rougeLsum': 0.6771554558791575}

# %%
# Base model ROUGE
model_rouge = rouge.compute(
    predictions=data_preprocessed["raw_generated_summary"],
    references=data_preprocessed["summary"][0:len(data_preprocessed["raw_generated_summary"])],
    use_aggregator=True,
    use_stemmer=True,
)
model_rouge
